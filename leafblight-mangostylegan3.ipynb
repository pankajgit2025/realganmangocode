# %%
# !pip install torch torchvision tqdm ninja click requests
# !pip install -r docs/requirements.txt
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.6.0+cu124)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (0.21.0+cu124)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (4.67.1)
# Requirement already satisfied: ninja in /usr/local/lib/python3.11/dist-packages (1.11.1.4)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (8.1.8)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (2.32.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torchvision) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision) (11.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests) (2025.4.26)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision) (2.4.1)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->torchvision) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->torchvision) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy->torchvision) (1.3.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy->torchvision) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy->torchvision) (2024.2.0)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.6 MB/s eta 0:00:000:00:0100:01
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.3 MB/s eta 0:00:000:00:0100:01
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 4.8 MB/s eta 0:00:000:00:0100:01
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 3.2 MB/s eta 0:00:000:00:0100:01
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 8.7 MB/s eta 0:00:000:00:0100:01
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 8.2 MB/s eta 0:00:000:00:0100:01
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 87.4 MB/s eta 0:00:00:00:0100:01
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.9.41
#     Uninstalling nvidia-nvjitlink-cu12-12.9.41:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.9.41
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.10.19
#     Uninstalling nvidia-curand-cu12-10.3.10.19:
#       Successfully uninstalled nvidia-curand-cu12-10.3.10.19
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.4.0.6
#     Uninstalling nvidia-cufft-cu12-11.4.0.6:
#       Successfully uninstalled nvidia-cufft-cu12-11.4.0.6
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.9.0.13
#     Uninstalling nvidia-cublas-cu12-12.9.0.13:
#       Successfully uninstalled nvidia-cublas-cu12-12.9.0.13
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.9.5
#     Uninstalling nvidia-cusparse-cu12-12.5.9.5:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.9.5
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.7.4.40
#     Uninstalling nvidia-cusolver-cu12-11.7.4.40:
#       Successfully uninstalled nvidia-cusolver-cu12-11.7.4.40
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'docs/requirements.txt'

# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.11/dist-packages (4.11.0.86)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.11/dist-packages (from opencv-python) (1.26.4)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.21.2->opencv-python) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.21.2->opencv-python) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.21.2->opencv-python) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.21.2->opencv-python) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.21.2->opencv-python) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.21.2->opencv-python) (2.4.1)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.21.2->opencv-python) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.21.2->opencv-python) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.21.2->opencv-python) (1.3.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.21.2->opencv-python) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.21.2->opencv-python) (2024.2.0)

# %%
# !git clone https://github.com/NVlabs/stylegan3.git
# Out:
# Cloning into 'stylegan3'...
# remote: Enumerating objects: 212, done.
# remote: Counting objects: 100% (163/163), done.
# remote: Compressing objects: 100% (73/73), done.
# remote: Total 212 (delta 99), reused 90 (delta 90), pack-reused 49 (from 1)
# Receiving objects: 100% (212/212), 4.16 MiB | 22.66 MiB/s, done.
# Resolving deltas: 100% (108/108), done.

# %%
# %cd stylegan3
# Out:
# /kaggle/working/stylegan3

# %%
# !pip install torch torchvision
# !pip install numpy scipy pillow requests tqdm pyspng ninja
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.6.0+cu124)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (0.21.0+cu124)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torchvision) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision) (11.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision) (2.4.1)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->torchvision) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->torchvision) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy->torchvision) (1.3.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy->torchvision) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy->torchvision) (2024.2.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (1.15.2)
# Requirement already satisfied: pillow in /usr/local/lib/python3.11/dist-packages (11.1.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (4.67.1)
# Collecting pyspng
#   Downloading pyspng-0.1.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.0 kB)
# Requirement already satisfied: ninja in /usr/local/lib/python3.11/dist-packages (1.11.1.4)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy) (2.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests) (2025.4.26)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy) (1.3.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy) (2024.2.0)
# Downloading pyspng-0.1.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (196 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.1/196.1 kB 4.2 MB/s eta 0:00:0000:01
# Installing collected packages: pyspng
# Successfully installed pyspng-0.1.3

# %%
# !pip install click dnnlib
# Out:
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (8.1.8)
# ERROR: Could not find a version that satisfies the requirement dnnlib (from versions: none)
# ERROR: No matching distribution found for dnnlib

# %%
# !pip install ninja pyspng click requests tqdm
# Out:
# Requirement already satisfied: ninja in /usr/local/lib/python3.11/dist-packages (1.11.1.4)
# Requirement already satisfied: pyspng in /usr/local/lib/python3.11/dist-packages (0.1.3)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (8.1.8)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (4.67.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from pyspng) (1.26.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests) (2025.4.26)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy->pyspng) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy->pyspng) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy->pyspng) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy->pyspng) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy->pyspng) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy->pyspng) (2.4.1)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->pyspng) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->pyspng) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy->pyspng) (1.3.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy->pyspng) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy->pyspng) (2024.2.0)

# %%
# !wget --content-disposition 'https://api.ngc.nvidia.com/v2/models/org/nvidia/team/research/stylegan3/1/files?redirect=true&path=stylegan3-t-afhqv2-512x512.pkl' -O stylegan3-t-afhqv2-512x512.pkl
# Out:
# --2025-05-27 02:55:29--  https://api.ngc.nvidia.com/v2/models/org/nvidia/team/research/stylegan3/1/files?redirect=true&path=stylegan3-t-afhqv2-512x512.pkl
# Resolving api.ngc.nvidia.com (api.ngc.nvidia.com)... 52.33.73.249, 52.24.8.111
# Connecting to api.ngc.nvidia.com (api.ngc.nvidia.com)|52.33.73.249|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://xfiles.ngc.nvidia.com/org/nvidia/team/research/models/stylegan3/versions/1/files/stylegan3-t-afhqv2-512x512.pkl?ssec-algo=AES256&versionId=R_QD.vNNZ1t.j3MLaYqfqNRct.7ezn7r&ssec-key=Z%2BHS%2Bpq522XQAiR8bmbQ1B4iYcLq5o%2FSkqRl7z%2FV0e5VniIsRRnyDD54opUfEl%2BcaRO61uxDc9PEIkK4fT5IC3wJ9S1v4aGzi8BQ6fATc7IbXsyvUO3Tt64pNfhd5cLGbMJ6iObiq%2BK2mR5%2B5JpY4kFolBY3PJLBZy4%2FwWjcmrObe1zz%2BlliBPDgxlYz4aL2YIf4ofyJRQ3w3Zamxthy3UvOOA8I4Y2VklKKr%2B86mz7ukhWt%2B3y%2F%2BX6E42qy5vyZRdKG3xgffZ63vuZ%2FeJB9krv1oyz5G54trRwBWyWcKWx7teoSV1nqJ3EjbOALchgOlvx9PpcBGq7A9wshPQD49FOBb3vjjgNaEnWfkfQ5QfmaeeBBj7lT9fzJvWpcQjVOMgVpAuD3gmiFt5xiO1attubq2rZMzoKrwQSf1VM8j1uYba45I9JVcDlp5c28EAhABRS1eSLiUrNP2QI7d2mP8mKfO9jiIcJU%2Bo4K%2BnNepgm%2BKDeeA6lved0oTcIJ9HUh&Signature=TwBBFRw8KtKt6bJtto8ojhXU6L5XLWwgmV5gaCg4WgwVyqxNauFomrEaVpIdoJn0lhbU6Ai7BCR5T8LqterEBFRJBCKS4GiTsnngJ9XhCZrfjapyLOGIKfsTykhr~FodgLoQdzUHKly-J6eGluAmHlU8BZRg6ZnXsqNwTr-pmjH-RN~DWRmylJ-bSLPK9Wo5KzCl5GYHtNte79bUlR~BEqcNntnSc~31iq4Pdrjo8bE8Ivnb3~vwwLekB4YsQZafTvX3RcPJ2gbamqMoRGX5gdUvZOISpHsCOL5aR4PzDB12Dp4bkRjXIX~ZStvFsryUP08~x9-8zj4HRoQcR9Iiig__&kid=bXJrLWU3OGM1M2FhZjE4YzRiNmJiNjlkYmRhZjcxNjA3YWEw&Expires=1748400929&Key-Pair-Id=KCX06E8E9L60W&ssec-enabled=true [following]
# --2025-05-27 02:55:29--  https://xfiles.ngc.nvidia.com/org/nvidia/team/research/models/stylegan3/versions/1/files/stylegan3-t-afhqv2-512x512.pkl?ssec-algo=AES256&versionId=R_QD.vNNZ1t.j3MLaYqfqNRct.7ezn7r&ssec-key=Z%2BHS%2Bpq522XQAiR8bmbQ1B4iYcLq5o%2FSkqRl7z%2FV0e5VniIsRRnyDD54opUfEl%2BcaRO61uxDc9PEIkK4fT5IC3wJ9S1v4aGzi8BQ6fATc7IbXsyvUO3Tt64pNfhd5cLGbMJ6iObiq%2BK2mR5%2B5JpY4kFolBY3PJLBZy4%2FwWjcmrObe1zz%2BlliBPDgxlYz4aL2YIf4ofyJRQ3w3Zamxthy3UvOOA8I4Y2VklKKr%2B86mz7ukhWt%2B3y%2F%2BX6E42qy5vyZRdKG3xgffZ63vuZ%2FeJB9krv1oyz5G54trRwBWyWcKWx7teoSV1nqJ3EjbOALchgOlvx9PpcBGq7A9wshPQD49FOBb3vjjgNaEnWfkfQ5QfmaeeBBj7lT9fzJvWpcQjVOMgVpAuD3gmiFt5xiO1attubq2rZMzoKrwQSf1VM8j1uYba45I9JVcDlp5c28EAhABRS1eSLiUrNP2QI7d2mP8mKfO9jiIcJU%2Bo4K%2BnNepgm%2BKDeeA6lved0oTcIJ9HUh&Signature=TwBBFRw8KtKt6bJtto8ojhXU6L5XLWwgmV5gaCg4WgwVyqxNauFomrEaVpIdoJn0lhbU6Ai7BCR5T8LqterEBFRJBCKS4GiTsnngJ9XhCZrfjapyLOGIKfsTykhr~FodgLoQdzUHKly-J6eGluAmHlU8BZRg6ZnXsqNwTr-pmjH-RN~DWRmylJ-bSLPK9Wo5KzCl5GYHtNte79bUlR~BEqcNntnSc~31iq4Pdrjo8bE8Ivnb3~vwwLekB4YsQZafTvX3RcPJ2gbamqMoRGX5gdUvZOISpHsCOL5aR4PzDB12Dp4bkRjXIX~ZStvFsryUP08~x9-8zj4HRoQcR9Iiig__&kid=bXJrLWU3OGM1M2FhZjE4YzRiNmJiNjlkYmRhZjcxNjA3YWEw&Expires=1748400929&Key-Pair-Id=KCX06E8E9L60W&ssec-enabled=true
# Resolving xfiles.ngc.nvidia.com (xfiles.ngc.nvidia.com)... 3.161.188.8, 3.161.188.79, 3.161.188.99, ...
# Connecting to xfiles.ngc.nvidia.com (xfiles.ngc.nvidia.com)|3.161.188.8|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 315163814 (301M) [application/x-zerosize]
# Saving to: ‘stylegan3-t-afhqv2-512x512.pkl’
#
# stylegan3-t-afhqv2- 100%[===================>] 300.56M   331MB/s    in 0.9s
#
# 2025-05-27 02:55:30 (331 MB/s) - ‘stylegan3-t-afhqv2-512x512.pkl’ saved [315163814/315163814]

# %%
# !python dataset_tool.py --source=/kaggle/input/lbmango512x512 --dest=LBlightMangoLeaf.zip
# Out:
# 100%|█████████████████████████████████████████| 949/949 [01:19<00:00, 11.99it/s]

# %%
ls /kaggle/working/*
# Out:
# avg_spectra.py   docs/            LBlightMangoLeaf.zip  torch_utils/
# calc_metrics.py  environment.yml  legacy.py             training/
# dataset_tool.py  gen_images.py    LICENSE.txt           train.py
# dnnlib/          gen_video.py     metrics/              visualizer.py
# Dockerfile       gui_utils/       README.md             viz/

# %%
# !pip install torch==2.0.1 torchvision==0.15.2
# Out:
# Collecting torch==2.0.1
#   Downloading torch-2.0.1-cp311-cp311-manylinux1_x86_64.whl.metadata (24 kB)
# Collecting torchvision==0.15.2
#   Downloading torchvision-0.15.2-cp311-cp311-manylinux1_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch==2.0.1) (3.18.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.11/dist-packages (from torch==2.0.1) (4.13.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/dist-packages (from torch==2.0.1) (1.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch==2.0.1) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch==2.0.1) (3.1.6)
# Collecting nvidia-cuda-nvrtc-cu11==11.7.99 (from torch==2.0.1)
#   Downloading nvidia_cuda_nvrtc_cu11-11.7.99-2-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu11==11.7.99 (from torch==2.0.1)
#   Downloading nvidia_cuda_runtime_cu11-11.7.99-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cuda-cupti-cu11==11.7.101 (from torch==2.0.1)
#   Downloading nvidia_cuda_cupti_cu11-11.7.101-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu11==8.5.0.96 (from torch==2.0.1)
#   Downloading nvidia_cudnn_cu11-8.5.0.96-2-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu11==11.10.3.66 (from torch==2.0.1)
#   Downloading nvidia_cublas_cu11-11.10.3.66-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cufft-cu11==10.9.0.58 (from torch==2.0.1)
#   Downloading nvidia_cufft_cu11-10.9.0.58-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu11==10.2.10.91 (from torch==2.0.1)
#   Downloading nvidia_curand_cu11-10.2.10.91-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusolver-cu11==11.4.0.1 (from torch==2.0.1)
#   Downloading nvidia_cusolver_cu11-11.4.0.1-2-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu11==11.7.4.91 (from torch==2.0.1)
#   Downloading nvidia_cusparse_cu11-11.7.4.91-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu11==2.14.3 (from torch==2.0.1)
#   Downloading nvidia_nccl_cu11-2.14.3-py3-none-manylinux1_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu11==11.7.91 (from torch==2.0.1)
#   Downloading nvidia_nvtx_cu11-11.7.91-py3-none-manylinux1_x86_64.whl.metadata (1.7 kB)
# Collecting triton==2.0.0 (from torch==2.0.1)
#   Downloading triton-2.0.0-1-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.0 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torchvision==0.15.2) (1.26.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from torchvision==0.15.2) (2.32.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision==0.15.2) (11.1.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch==2.0.1) (75.2.0)
# Requirement already satisfied: wheel in /usr/local/lib/python3.11/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch==2.0.1) (0.45.1)
# Requirement already satisfied: cmake in /usr/local/lib/python3.11/dist-packages (from triton==2.0.0->torch==2.0.1) (3.31.6)
# Collecting lit (from triton==2.0.0->torch==2.0.1)
#   Downloading lit-18.1.8-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch==2.0.1) (3.0.2)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision==0.15.2) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision==0.15.2) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision==0.15.2) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision==0.15.2) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision==0.15.2) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision==0.15.2) (2.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->torchvision==0.15.2) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->torchvision==0.15.2) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->torchvision==0.15.2) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->torchvision==0.15.2) (2025.4.26)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy->torch==2.0.1) (1.3.0)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->torchvision==0.15.2) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->torchvision==0.15.2) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy->torchvision==0.15.2) (1.3.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy->torchvision==0.15.2) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy->torchvision==0.15.2) (2024.2.0)
# Downloading torch-2.0.1-cp311-cp311-manylinux1_x86_64.whl (619.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 619.9/619.9 MB 2.7 MB/s eta 0:00:000:00:0100:01
# Downloading torchvision-0.15.2-cp311-cp311-manylinux1_x86_64.whl (6.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 90.5 MB/s eta 0:00:00:00:01
# Downloading nvidia_cublas_cu11-11.10.3.66-py3-none-manylinux1_x86_64.whl (317.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.1/317.1 MB 5.3 MB/s eta 0:00:000:00:0100:01
# Downloading nvidia_cuda_cupti_cu11-11.7.101-py3-none-manylinux1_x86_64.whl (11.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 98.1 MB/s eta 0:00:00:00:010:01
# Downloading nvidia_cuda_nvrtc_cu11-11.7.99-2-py3-none-manylinux1_x86_64.whl (21.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.0/21.0 MB 82.9 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cuda_runtime_cu11-11.7.99-py3-none-manylinux1_x86_64.whl (849 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.3/849.3 kB 22.8 MB/s eta 0:00:00:00:01
# Downloading nvidia_cudnn_cu11-8.5.0.96-2-py3-none-manylinux1_x86_64.whl (557.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 557.1/557.1 MB 1.9 MB/s eta 0:00:000:00:0100:01
# Downloading nvidia_cufft_cu11-10.9.0.58-py3-none-manylinux2014_x86_64.whl (168.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.4/168.4 MB 2.1 MB/s eta 0:00:000:00:0100:01
# Downloading nvidia_curand_cu11-10.2.10.91-py3-none-manylinux1_x86_64.whl (54.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.6/54.6 MB 33.6 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cusolver_cu11-11.4.0.1-2-py3-none-manylinux1_x86_64.whl (102.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.6/102.6 MB 15.9 MB/s eta 0:00:00:00:010:01
# Downloading nvidia_cusparse_cu11-11.7.4.91-py3-none-manylinux1_x86_64.whl (173.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 173.2/173.2 MB 9.6 MB/s eta 0:00:000:00:0100:01
# Downloading nvidia_nccl_cu11-2.14.3-py3-none-manylinux1_x86_64.whl (177.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.1/177.1 MB 9.4 MB/s eta 0:00:000:00:0100:01
# Downloading nvidia_nvtx_cu11-11.7.91-py3-none-manylinux1_x86_64.whl (98 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.6/98.6 kB 4.6 MB/s eta 0:00:00
# Downloading triton-2.0.0-1-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (63.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.3/63.3 MB 26.9 MB/s eta 0:00:00:00:0100:01
# Downloading lit-18.1.8-py3-none-any.whl (96 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.4/96.4 kB 4.9 MB/s eta 0:00:00
# Installing collected packages: lit, nvidia-nvtx-cu11, nvidia-nccl-cu11, nvidia-cusparse-cu11, nvidia-curand-cu11, nvidia-cufft-cu11, nvidia-cuda-runtime-cu11, nvidia-cuda-nvrtc-cu11, nvidia-cuda-cupti-cu11, nvidia-cublas-cu11, nvidia-cusolver-cu11, nvidia-cudnn-cu11, triton, torch, torchvision
#   Attempting uninstall: triton
#     Found existing installation: triton 3.2.0
#     Uninstalling triton-3.2.0:
#       Successfully uninstalled triton-3.2.0
#   Attempting uninstall: torch
#     Found existing installation: torch 2.6.0+cu124
#     Uninstalling torch-2.6.0+cu124:
#       Successfully uninstalled torch-2.6.0+cu124
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.21.0+cu124
#     Uninstalling torchvision-0.21.0+cu124:
#       Successfully uninstalled torchvision-0.21.0+cu124
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pytorch-lightning 2.5.1.post0 requires torch>=2.1.0, but you have torch 2.0.1 which is incompatible.
# torchaudio 2.6.0+cu124 requires torch==2.6.0, but you have torch 2.0.1 which is incompatible.
# Successfully installed lit-18.1.8 nvidia-cublas-cu11-11.10.3.66 nvidia-cuda-cupti-cu11-11.7.101 nvidia-cuda-nvrtc-cu11-11.7.99 nvidia-cuda-runtime-cu11-11.7.99 nvidia-cudnn-cu11-8.5.0.96 nvidia-cufft-cu11-10.9.0.58 nvidia-curand-cu11-10.2.10.91 nvidia-cusolver-cu11-11.4.0.1 nvidia-cusparse-cu11-11.7.4.91 nvidia-nccl-cu11-2.14.3 nvidia-nvtx-cu11-11.7.91 torch-2.0.1 torchvision-0.15.2 triton-2.0.0

# %%
# !python train.py \
  --outdir=training-runs \
  --data=LBlightMangoLeaf.zip \
  --gpus=2 \
  --batch=4 \
  --gamma=8.2 \
  --snap=10 \
  --cfg=stylegan3-t \
  --mirror=0 \
  --aug=ada \
  --kimg=300 \
  --cbase=16384 --cmax=64 \
  --mbstd-group=2 \
  --metrics=none
# Out:
# Training options:
# {
#   "G_kwargs": {
#     "class_name": "training.networks_stylegan3.Generator",
#     "z_dim": 512,
#     "w_dim": 512,
#     "mapping_kwargs": {
#       "num_layers": 2
#     },
#     "channel_base": 16384,
#     "channel_max": 64,
#     "magnitude_ema_beta": 0.9998613801725043
#   },
#   "D_kwargs": {
#     "class_name": "training.networks_stylegan2.Discriminator",
#     "block_kwargs": {
#       "freeze_layers": 0
#     },
#     "mapping_kwargs": {},
#     "epilogue_kwargs": {
#       "mbstd_group_size": 2
#     },
#     "channel_base": 16384,
#     "channel_max": 64
#   },
#   "G_opt_kwargs": {
#     "class_name": "torch.optim.Adam",
#     "betas": [
#       0,
#       0.99
#     ],
#     "eps": 1e-08,
#     "lr": 0.0025
#   },
#   "D_opt_kwargs": {
#     "class_name": "torch.optim.Adam",
#     "betas": [
#       0,
#       0.99
#     ],
#     "eps": 1e-08,
#     "lr": 0.002
#   },
#   "loss_kwargs": {
#     "class_name": "training.loss.StyleGAN2Loss",
#     "r1_gamma": 8.2
#   },
#   "data_loader_kwargs": {
#     "pin_memory": true,
#     "prefetch_factor": 2,
#     "num_workers": 3
#   },
#   "training_set_kwargs": {
#     "class_name": "training.dataset.ImageFolderDataset",
#     "path": "LBlightMangoLeaf.zip",
#     "use_labels": false,
#     "max_size": 949,
#     "xflip": false,
#     "resolution": 1024,
#     "random_seed": 0
#   },
#   "num_gpus": 2,
#   "batch_size": 4,
#   "batch_gpu": 2,
#   "metrics": [],
#   "total_kimg": 300,
#   "kimg_per_tick": 4,
#   "image_snapshot_ticks": 10,
#   "network_snapshot_ticks": 10,
#   "random_seed": 0,
#   "ema_kimg": 1.25,
#   "augment_kwargs": {
#     "class_name": "training.augment.AugmentPipe",
#     "xflip": 1,
#     "rotate90": 1,
#     "xint": 1,
#     "scale": 1,
#     "rotate": 1,
#     "aniso": 1,
#     "xfrac": 1,
#     "brightness": 1,
#     "contrast": 1,
#     "lumaflip": 1,
#     "hue": 1,
#     "saturation": 1
#   },
#   "ada_target": 0.6,
#   "run_dir": "training-runs/00000-stylegan3-t-LBlightMangoLeaf-gpus2-batch4-gamma8.2"
# }
#
# Output directory:    training-runs/00000-stylegan3-t-LBlightMangoLeaf-gpus2-batch4-gamma8.2
# Number of GPUs:      2
# Batch size:          4 images
# Training duration:   300 kimg
# Dataset path:        LBlightMangoLeaf.zip
# Dataset size:        949 images
# Dataset resolution:  1024
# Dataset labels:      False
# Dataset x-flips:     False
#
# Creating output directory...
# Launching processes...
# Loading training set...
#
# Num images:  949
# Image shape: [3, 1024, 1024]
# Label shape: [0]
#
# Constructing networks...
# Setting up PyTorch plugin "bias_act_plugin"... Done.
# Setting up PyTorch plugin "filtered_lrelu_plugin"... Done.
#
# Generator                     Parameters  Buffers  Output shape         Datatype
# ---                           ---         ---      ---                  ---
# mapping.fc0                   262656      -        [2, 512]             float32
# mapping.fc1                   262656      -        [2, 512]             float32
# mapping                       -           512      [2, 16, 512]         float32
# synthesis.input.affine        2052        -        [2, 4]               float32
# synthesis.input               4096        201      [2, 64, 36, 36]      float32
# synthesis.L0_36_64.affine     32832       -        [2, 64]              float32
# synthesis.L0_36_64            36928       25       [2, 64, 36, 36]      float32
# synthesis.L1_36_64.affine     32832       -        [2, 64]              float32
# synthesis.L1_36_64            36928       25       [2, 64, 36, 36]      float32
# synthesis.L2_52_64.affine     32832       -        [2, 64]              float32
# synthesis.L2_52_64            36928       37       [2, 64, 52, 52]      float32
# synthesis.L3_52_64.affine     32832       -        [2, 64]              float32
# synthesis.L3_52_64            36928       25       [2, 64, 52, 52]      float32
# synthesis.L4_84_64.affine     32832       -        [2, 64]              float32
# synthesis.L4_84_64            36928       37       [2, 64, 84, 84]      float32
# synthesis.L5_148_64.affine    32832       -        [2, 64]              float32
# synthesis.L5_148_64           36928       37       [2, 64, 148, 148]    float16
# synthesis.L6_148_64.affine    32832       -        [2, 64]              float32
# synthesis.L6_148_64           36928       25       [2, 64, 148, 148]    float16
# synthesis.L7_276_64.affine    32832       -        [2, 64]              float32
# synthesis.L7_276_64           36928       37       [2, 64, 276, 276]    float16
# synthesis.L8_276_64.affine    32832       -        [2, 64]              float32
# synthesis.L8_276_64           36928       25       [2, 64, 276, 276]    float16
# synthesis.L9_532_64.affine    32832       -        [2, 64]              float32
# synthesis.L9_532_64           36928       37       [2, 64, 532, 532]    float16
# synthesis.L10_1044_40.affine  32832       -        [2, 64]              float32
# synthesis.L10_1044_40         23080       37       [2, 40, 1044, 1044]  float16
# synthesis.L11_1044_25.affine  20520       -        [2, 40]              float32
# synthesis.L11_1044_25         9025        25       [2, 25, 1044, 1044]  float16
# synthesis.L12_1044_16.affine  12825       -        [2, 25]              float32
# synthesis.L12_1044_16         3616        25       [2, 16, 1044, 1044]  float16
# synthesis.L13_1024_16.affine  8208        -        [2, 16]              float32
# synthesis.L13_1024_16         2320        25       [2, 16, 1024, 1024]  float16
# synthesis.L14_1024_3.affine   8208        -        [2, 16]              float32
# synthesis.L14_1024_3          51          1        [2, 3, 1024, 1024]   float16
# synthesis                     -           -        [2, 3, 1024, 1024]   float32
# ---                           ---         ---      ---                  ---
# Total                         1349745     1136     -                    -
#
# Setting up PyTorch plugin "upfirdn2d_plugin"... Done.
#
# Discriminator  Parameters  Buffers  Output shape         Datatype
# ---            ---         ---      ---                  ---
# b1024.fromrgb  64          16       [2, 16, 1024, 1024]  float16
# b1024.skip     512         16       [2, 32, 512, 512]    float16
# b1024.conv0    2320        16       [2, 16, 1024, 1024]  float16
# b1024.conv1    4640        16       [2, 32, 512, 512]    float16
# b1024          -           16       [2, 32, 512, 512]    float16
# b512.skip      2048        16       [2, 64, 256, 256]    float16
# b512.conv0     9248        16       [2, 32, 512, 512]    float16
# b512.conv1     18496       16       [2, 64, 256, 256]    float16
# b512           -           16       [2, 64, 256, 256]    float16
# b256.skip      4096        16       [2, 64, 128, 128]    float16
# b256.conv0     36928       16       [2, 64, 256, 256]    float16
# b256.conv1     36928       16       [2, 64, 128, 128]    float16
# b256           -           16       [2, 64, 128, 128]    float16
# b128.skip      4096        16       [2, 64, 64, 64]      float16
# b128.conv0     36928       16       [2, 64, 128, 128]    float16
# b128.conv1     36928       16       [2, 64, 64, 64]      float16
# b128           -           16       [2, 64, 64, 64]      float16
# b64.skip       4096        16       [2, 64, 32, 32]      float32
# b64.conv0      36928       16       [2, 64, 64, 64]      float32
# b64.conv1      36928       16       [2, 64, 32, 32]      float32
# b64            -           16       [2, 64, 32, 32]      float32
# b32.skip       4096        16       [2, 64, 16, 16]      float32
# b32.conv0      36928       16       [2, 64, 32, 32]      float32
# b32.conv1      36928       16       [2, 64, 16, 16]      float32
# b32            -           16       [2, 64, 16, 16]      float32
# b16.skip       4096        16       [2, 64, 8, 8]        float32
# b16.conv0      36928       16       [2, 64, 16, 16]      float32
# b16.conv1      36928       16       [2, 64, 8, 8]        float32
# b16            -           16       [2, 64, 8, 8]        float32
# b8.skip        4096        16       [2, 64, 4, 4]        float32
# b8.conv0       36928       16       [2, 64, 8, 8]        float32
# b8.conv1       36928       16       [2, 64, 4, 4]        float32
# b8             -           16       [2, 64, 4, 4]        float32
# b4.mbstd       -           -        [2, 65, 4, 4]        float32
# b4.conv        37504       16       [2, 64, 4, 4]        float32
# b4.fc          65600       -        [2, 64]              float32
# b4.out         65          -        [2, 1]               float32
# ---            ---         ---      ---                  ---
# Total          608209      544      -                    -
#
# Setting up augmentation...
# Distributing across 2 GPUs...
# Setting up training phases...
# Exporting sample images...
# Initializing logs...
# 2025-05-27 06:44:41.948239: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1748328282.504293     173 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1748328282.651984     173 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Training for 300 kimg...
#
# tick 0     kimg 0.0      time 3m 26s       sec/tick 25.7    sec/kimg 6418.07 maintenance 180.2  cpumem 3.96   gpumem 12.85  reserved 13.32  augment 0.000
# tick 1     kimg 4.0      time 14m 27s      sec/tick 655.6   sec/kimg 163.90  maintenance 5.2    cpumem 4.29   gpumem 1.62   reserved 3.44   augment 0.005
# tick 2     kimg 8.0      time 25m 38s      sec/tick 671.3   sec/kimg 167.82  maintenance 0.1    cpumem 4.29   gpumem 1.62   reserved 3.44   augment 0.006
# tick 3     kimg 12.0     time 36m 53s      sec/tick 674.0   sec/kimg 168.50  maintenance 0.5    cpumem 4.29   gpumem 1.62   reserved 3.44   augment 0.007
# tick 4     kimg 16.0     time 48m 03s      sec/tick 670.2   sec/kimg 167.55  maintenance 0.1    cpumem 4.29   gpumem 1.63   reserved 3.44   augment 0.010
# tick 5     kimg 20.0     time 59m 14s      sec/tick 670.3   sec/kimg 167.58  maintenance 0.5    cpumem 4.29   gpumem 1.63   reserved 3.44   augment 0.013
# tick 6     kimg 24.0     time 1h 10m 26s   sec/tick 671.8   sec/kimg 167.94  maintenance 0.1    cpumem 4.29   gpumem 1.65   reserved 3.44   augment 0.018
# tick 7     kimg 28.0     time 1h 21m 36s   sec/tick 669.6   sec/kimg 167.40  maintenance 0.5    cpumem 4.29   gpumem 1.63   reserved 3.44   augment 0.025
# tick 8     kimg 32.0     time 1h 32m 45s   sec/tick 669.6   sec/kimg 167.40  maintenance 0.1    cpumem 4.29   gpumem 1.63   reserved 3.44   augment 0.032
# tick 9     kimg 36.0     time 1h 43m 57s   sec/tick 671.1   sec/kimg 167.79  maintenance 0.6    cpumem 4.29   gpumem 1.66   reserved 3.80   augment 0.039
# tick 10    kimg 40.0     time 1h 55m 12s   sec/tick 674.5   sec/kimg 168.63  maintenance 0.1    cpumem 4.29   gpumem 1.66   reserved 3.80   augment 0.047

# %%
#FID SCORE
# !python /kaggle/working/stylegan3/calc_metrics.py \
  --gpus=1 \
  --data=/kaggle/input/anthmango512x512 \
  --network=/kaggle/input/trained/other/default/1/network-snapshot-000240.pkl \
  --metrics=fid50k_full
# Out:
# Loading network from "/kaggle/input/trained/other/default/1/network-snapshot-000240.pkl"...
# Dataset options:
# {
#   "class_name": "training.dataset.ImageFolderDataset",
#   "path": "/kaggle/input/anthmango512x512",
#   "resolution": 1024,
#   "use_labels": false
# }
# Launching processes...
# Setting up PyTorch plugin "bias_act_plugin"... /usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py:2059: UserWarning: TORCH_CUDA_ARCH_LIST is not set, all archs for visible cards are included for compilation.
# If this is not desired, please set os.environ['TORCH_CUDA_ARCH_LIST'].
#   warnings.warn(
# Done.
# Setting up PyTorch plugin "filtered_lrelu_plugin"... /usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py:2059: UserWarning: TORCH_CUDA_ARCH_LIST is not set, all archs for visible cards are included for compilation.
# If this is not desired, please set os.environ['TORCH_CUDA_ARCH_LIST'].
#   warnings.warn(
# Done.
#
# Generator                     Parameters  Buffers  Output shape         Datatype
# ---                           ---         ---      ---                  ---
# mapping.fc0                   262656      -        [1, 512]             float32
# mapping.fc1                   262656      -        [1, 512]             float32
# mapping                       -           512      [1, 16, 512]         float32
# synthesis.input.affine        2052        -        [1, 4]               float32
# synthesis.input               4096        201      [1, 64, 36, 36]      float32
# synthesis.L0_36_64.affine     32832       -        [1, 64]              float32
# synthesis.L0_36_64            36928       25       [1, 64, 36, 36]      float32
# synthesis.L1_36_64.affine     32832       -        [1, 64]              float32
# synthesis.L1_36_64            36928       25       [1, 64, 36, 36]      float32
# synthesis.L2_52_64.affine     32832       -        [1, 64]              float32
# synthesis.L2_52_64            36928       37       [1, 64, 52, 52]      float32
# synthesis.L3_52_64.affine     32832       -        [1, 64]              float32
# synthesis.L3_52_64            36928       25       [1, 64, 52, 52]      float32
# synthesis.L4_84_64.affine     32832       -        [1, 64]              float32
# synthesis.L4_84_64            36928       37       [1, 64, 84, 84]      float32
# synthesis.L5_148_64.affine    32832       -        [1, 64]              float32
# synthesis.L5_148_64           36928       37       [1, 64, 148, 148]    float16
# synthesis.L6_148_64.affine    32832       -        [1, 64]              float32
# synthesis.L6_148_64           36928       25       [1, 64, 148, 148]    float16
# synthesis.L7_276_64.affine    32832       -        [1, 64]              float32
# synthesis.L7_276_64           36928       37       [1, 64, 276, 276]    float16
# synthesis.L8_276_64.affine    32832       -        [1, 64]              float32
# synthesis.L8_276_64           36928       25       [1, 64, 276, 276]    float16
# synthesis.L9_532_64.affine    32832       -        [1, 64]              float32
# synthesis.L9_532_64           36928       37       [1, 64, 532, 532]    float16
# synthesis.L10_1044_40.affine  32832       -        [1, 64]              float32
# synthesis.L10_1044_40         23080       37       [1, 40, 1044, 1044]  float16
# synthesis.L11_1044_25.affine  20520       -        [1, 40]              float32
# synthesis.L11_1044_25         9025        25       [1, 25, 1044, 1044]  float16
# synthesis.L12_1044_16.affine  12825       -        [1, 25]              float32
# synthesis.L12_1044_16         3616        25       [1, 16, 1044, 1044]  float16
# synthesis.L13_1024_16.affine  8208        -        [1, 16]              float32
# synthesis.L13_1024_16         2320        25       [1, 16, 1024, 1024]  float16
# synthesis.L14_1024_3.affine   8208        -        [1, 16]              float32
# synthesis.L14_1024_3          51          1        [1, 3, 1024, 1024]   float16
# synthesis                     -           -        [1, 3, 1024, 1024]   float32
# ---                           ---         ---      ---                  ---
# Total                         1349745     1136     -                    -
#
# Calculating fid50k_full...
# Downloading https://api.ngc.nvidia.com/v2/models/nvidia/research/stylegan3/versions/1/files/metrics/inception-2015-12-05.pkl ... done
# dataset features    items 886     time 17s          ms/item 19.56
# generator features  items 1024    time 42s          ms/item 40.53
# generator features  items 2048    time 1m 25s       ms/item 42.77
# generator features  items 3072    time 2m 12s       ms/item 45.61
# generator features  items 4096    time 3m 00s       ms/item 46.46
# generator features  items 5120    time 3m 47s       ms/item 46.20
# generator features  items 6144    time 4m 34s       ms/item 46.22
# generator features  items 7168    time 5m 22s       ms/item 46.41
# generator features  items 8192    time 6m 09s       ms/item 46.35
# generator features  items 9216    time 6m 57s       ms/item 46.20
# generator features  items 10240   time 7m 44s       ms/item 46.23
# generator features  items 11264   time 8m 31s       ms/item 46.40
# generator features  items 12288   time 9m 19s       ms/item 46.41
# generator features  items 13312   time 10m 06s      ms/item 46.28
# generator features  items 14336   time 10m 54s      ms/item 46.22
# generator features  items 15360   time 11m 41s      ms/item 46.21
# generator features  items 16384   time 12m 28s      ms/item 46.22
# generator features  items 17408   time 13m 16s      ms/item 46.22
# generator features  items 18432   time 14m 03s      ms/item 46.23
# generator features  items 19456   time 14m 50s      ms/item 46.22
# generator features  items 20480   time 15m 38s      ms/item 46.21
# generator features  items 21504   time 16m 25s      ms/item 46.20
# generator features  items 22528   time 17m 12s      ms/item 46.27
# generator features  items 23552   time 18m 00s      ms/item 46.39
# generator features  items 24576   time 18m 47s      ms/item 46.44
# generator features  items 25600   time 19m 35s      ms/item 46.40
# generator features  items 26624   time 20m 22s      ms/item 46.37
# generator features  items 27648   time 21m 10s      ms/item 46.28
# generator features  items 28672   time 21m 57s      ms/item 46.26
# generator features  items 29696   time 22m 44s      ms/item 46.25
# generator features  items 30720   time 23m 32s      ms/item 46.35
# generator features  items 31744   time 24m 19s      ms/item 46.44
# generator features  items 32768   time 25m 07s      ms/item 46.50
# generator features  items 33792   time 25m 55s      ms/item 46.39
# generator features  items 34816   time 26m 42s      ms/item 46.29
# generator features  items 35840   time 27m 29s      ms/item 46.23
# generator features  items 36864   time 28m 17s      ms/item 46.33
# generator features  items 37888   time 29m 04s      ms/item 46.43
# generator features  items 38912   time 29m 52s      ms/item 46.45
# generator features  items 39936   time 30m 39s      ms/item 46.35
# generator features  items 40960   time 31m 27s      ms/item 46.31
# generator features  items 41984   time 32m 14s      ms/item 46.39
# generator features  items 43008   time 33m 02s      ms/item 46.45
# generator features  items 44032   time 33m 49s      ms/item 46.44
# generator features  items 45056   time 34m 37s      ms/item 46.39
# generator features  items 46080   time 35m 24s      ms/item 46.28
# generator features  items 47104   time 36m 12s      ms/item 46.25
# generator features  items 48128   time 36m 59s      ms/item 46.21
# generator features  items 49152   time 37m 46s      ms/item 46.20
# generator features  items 50000   time 38m 28s      ms/item 48.86
# {"results": {"fid50k_full": 75.0637627939511}, "metric": "fid50k_full", "total_time": 2335.2022845745087, "total_time_str": "38m 55s", "num_gpus": 1, "snapshot_pkl": "/kaggle/input/trained/other/default/1/network-snapshot-000240.pkl", "timestamp": 1748313792.6779463}
#
# Exiting...

# %%
# !python gen_images.py \
  --outdir=ANTHgenerated-images \
  --trunc=0.5 \
  --seeds=0-99 \
   --network=/kaggle/input/trained/other/default/1/network-snapshot-000240.pkl
# Out:
# Loading networks from "/kaggle/input/trained/other/default/1/network-snapshot-000240.pkl"...
# Generating image for seed 0 (0/100) ...
# Setting up PyTorch plugin "bias_act_plugin"... /usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py:2059: UserWarning: TORCH_CUDA_ARCH_LIST is not set, all archs for visible cards are included for compilation.
# If this is not desired, please set os.environ['TORCH_CUDA_ARCH_LIST'].
#   warnings.warn(
# Done.
# Setting up PyTorch plugin "filtered_lrelu_plugin"... /usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py:2059: UserWarning: TORCH_CUDA_ARCH_LIST is not set, all archs for visible cards are included for compilation.
# If this is not desired, please set os.environ['TORCH_CUDA_ARCH_LIST'].
#   warnings.warn(
# Done.
# Generating image for seed 1 (1/100) ...
# Generating image for seed 2 (2/100) ...
# Generating image for seed 3 (3/100) ...
# Generating image for seed 4 (4/100) ...
# Generating image for seed 5 (5/100) ...
# Generating image for seed 6 (6/100) ...
# Generating image for seed 7 (7/100) ...
# Generating image for seed 8 (8/100) ...
# Generating image for seed 9 (9/100) ...
# Generating image for seed 10 (10/100) ...
# Generating image for seed 11 (11/100) ...
# Generating image for seed 12 (12/100) ...
# Generating image for seed 13 (13/100) ...
# Generating image for seed 14 (14/100) ...
# Generating image for seed 15 (15/100) ...
# Generating image for seed 16 (16/100) ...
# Generating image for seed 17 (17/100) ...
# Generating image for seed 18 (18/100) ...
# Generating image for seed 19 (19/100) ...
# Generating image for seed 20 (20/100) ...
# Generating image for seed 21 (21/100) ...
# Generating image for seed 22 (22/100) ...
# Generating image for seed 23 (23/100) ...
# Generating image for seed 24 (24/100) ...
# Generating image for seed 25 (25/100) ...
# Generating image for seed 26 (26/100) ...
# Generating image for seed 27 (27/100) ...
# Generating image for seed 28 (28/100) ...
# Generating image for seed 29 (29/100) ...
# Generating image for seed 30 (30/100) ...
# Generating image for seed 31 (31/100) ...
# Generating image for seed 32 (32/100) ...
# Generating image for seed 33 (33/100) ...
# Generating image for seed 34 (34/100) ...
# Generating image for seed 35 (35/100) ...
# Generating image for seed 36 (36/100) ...
# Generating image for seed 37 (37/100) ...
# Generating image for seed 38 (38/100) ...
# Generating image for seed 39 (39/100) ...
# Generating image for seed 40 (40/100) ...
# Generating image for seed 41 (41/100) ...
# Generating image for seed 42 (42/100) ...
# Generating image for seed 43 (43/100) ...
# Generating image for seed 44 (44/100) ...
# Generating image for seed 45 (45/100) ...
# Generating image for seed 46 (46/100) ...
# Generating image for seed 47 (47/100) ...
# Generating image for seed 48 (48/100) ...
# Generating image for seed 49 (49/100) ...
# Generating image for seed 50 (50/100) ...
# Generating image for seed 51 (51/100) ...
# Generating image for seed 52 (52/100) ...
# Generating image for seed 53 (53/100) ...
# Generating image for seed 54 (54/100) ...
# Generating image for seed 55 (55/100) ...
# Generating image for seed 56 (56/100) ...
# Generating image for seed 57 (57/100) ...
# Generating image for seed 58 (58/100) ...
# Generating image for seed 59 (59/100) ...
# Generating image for seed 60 (60/100) ...
# Generating image for seed 61 (61/100) ...
# Generating image for seed 62 (62/100) ...
# Generating image for seed 63 (63/100) ...
# Generating image for seed 64 (64/100) ...
# Generating image for seed 65 (65/100) ...
# Generating image for seed 66 (66/100) ...
# Generating image for seed 67 (67/100) ...
# Generating image for seed 68 (68/100) ...
# Generating image for seed 69 (69/100) ...
# Generating image for seed 70 (70/100) ...
# Generating image for seed 71 (71/100) ...
# Generating image for seed 72 (72/100) ...
# Generating image for seed 73 (73/100) ...
# Generating image for seed 74 (74/100) ...
# Generating image for seed 75 (75/100) ...
# Generating image for seed 76 (76/100) ...
# Generating image for seed 77 (77/100) ...
# Generating image for seed 78 (78/100) ...
# Generating image for seed 79 (79/100) ...
# Generating image for seed 80 (80/100) ...
# Generating image for seed 81 (81/100) ...
# Generating image for seed 82 (82/100) ...
# Generating image for seed 83 (83/100) ...
# Generating image for seed 84 (84/100) ...
# Generating image for seed 85 (85/100) ...
# Generating image for seed 86 (86/100) ...
# Generating image for seed 87 (87/100) ...
# Generating image for seed 88 (88/100) ...
# Generating image for seed 89 (89/100) ...
# Generating image for seed 90 (90/100) ...
# Generating image for seed 91 (91/100) ...
# Generating image for seed 92 (92/100) ...
# Generating image for seed 93 (93/100) ...
# Generating image for seed 94 (94/100) ...
# Generating image for seed 95 (95/100) ...
# Generating image for seed 96 (96/100) ...
# Generating image for seed 97 (97/100) ...
# Generating image for seed 98 (98/100) ...
# Generating image for seed 99 (99/100) ...

# %%
#ziping generated image
# !zip -r ANTHgenerated-images1.zip ANTHgenerated-images
# Out:
#   adding: ANTHgenerated-images/ (stored 0%)
#   adding: ANTHgenerated-images/seed0012.png (deflated 0%)
#   adding: ANTHgenerated-images/seed0066.png (deflated 0%)
#   adding: ANTHgenerated-images/seed0024.png (deflated 1%)
#   adding: ANTHgenerated-images/seed0033.png (deflated 1%)
#   adding: ANTHgenerated-images/seed0089.png (deflated 0%)
#   adding: ANTHgenerated-images/seed0076.png (deflated 0%)
#   adding: ANTHgenerated-images/seed0084.png (deflated 1%)
#   adding: ANTHgenerated-images/seed0003.png (deflated 0%)
#   adding: ANTHgenerated-images/seed0093.png (deflated 0%)
#   adding: ANTHgenerated-images/seed0028.png (deflated 0%)
#   adding: ANTHgenerated-images/seed0031.png (deflated 0%)
#   adding: ANTHgenerated-images/seed0010.png (deflated 0%)
#   adding: ANTHgenerated-images/seed0074.png (deflated 0%)
#   adding: ANTHgenerated-images/seed0006.png (deflated 0%)
#   adding: ANTHgenerated-images/seed0086.png (deflated 1%)
#   adding: ANTHgenerated-images/seed0043.png (deflated 1%)
#   adding: ANTHgenerated-images/seed0063.png (deflated 1%)
#   adding: ANTHgenerated-images/seed0052.png (deflated 1%)
#   adding: ANTHgenerated-images/seed0019.png (deflated 1%)
#   adding: ANTHgenerated-images/seed0068.png (deflated 1%)
#   adding: ANTHgenerated-images/seed0008.png (deflated 1%)
#   adding: ANTHgenerated-images/seed0011.png (deflated 1%)
#   adding: ANTHgenerated-images/seed0070.png (deflated 1%)
#   adding: ANTHgenerated-images/seed0026.png (deflated 0%)
#   adding: ANTHgenerated-images/seed0034.png (deflated 1%)
#   adding: ANTHgenerated-images/seed0094.png (deflated 1%)
#   adding: ANTHgenerated-images/seed0016.png (deflated 1%)
#   adding: ANTHgenerated-images/seed0065.png (deflated 1%)
#   adding: ANTHgenerated-images/seed0073.png (deflated 0%)
#   adding: ANTHgenerated-images/seed0077.png (deflated 1%)
#   adding: ANTHgenerated-images/seed0039.png (deflated 1%)
#   adding: ANTHgenerated-images/seed0032.png (deflated 0%)
#   adding: ANTHgenerated-images/seed0002.png (deflated 1%)
#   adding: ANTHgenerated-images/seed0053.png (deflated 0%)
#   adding: ANTHgenerated-images/seed0072.png (deflated 1%)
#   adding: ANTHgenerated-images/seed0014.png (deflated 1%)
#   adding: ANTHgenerated-images/seed0042.png (deflated 0%)
#   adding: ANTHgenerated-images/seed0081.png (deflated 1%)
#   adding: ANTHgenerated-images/seed0000.png (deflated 0%)
#   adding: ANTHgenerated-images/seed0005.png (deflated 0%)
#   adding: ANTHgenerated-images/seed0069.png (deflated 1%)
#   adding: ANTHgenerated-images/seed0046.png (deflated 1%)
#   adding: ANTHgenerated-images/seed0021.png (deflated 1%)
#   adding: ANTHgenerated-images/seed0041.png (deflated 0%)
#   adding: ANTHgenerated-images/seed0095.png (deflated 0%)
#   adding: ANTHgenerated-images/seed0097.png (deflated 1%)
#   adding: ANTHgenerated-images/seed0059.png (deflated 1%)
#   adding: ANTHgenerated-images/seed0049.png (deflated 0%)
#   adding: ANTHgenerated-images/seed0023.png (deflated 0%)
#   adding: ANTHgenerated-images/seed0045.png (deflated 0%)
#   adding: ANTHgenerated-images/seed0088.png (deflated 1%)
#   adding: ANTHgenerated-images/seed0080.png (deflated 0%)
#   adding: ANTHgenerated-images/seed0057.png (deflated 1%)
#   adding: ANTHgenerated-images/seed0029.png (deflated 1%)
#   adding: ANTHgenerated-images/seed0061.png (deflated 1%)
#   adding: ANTHgenerated-images/seed0038.png (deflated 1%)
#   adding: ANTHgenerated-images/seed0040.png (deflated 0%)
#   adding: ANTHgenerated-images/seed0007.png (deflated 1%)
#   adding: ANTHgenerated-images/seed0048.png (deflated 0%)
#   adding: ANTHgenerated-images/seed0009.png (deflated 0%)
#   adding: ANTHgenerated-images/seed0082.png (deflated 1%)
#   adding: ANTHgenerated-images/seed0090.png (deflated 1%)
#   adding: ANTHgenerated-images/seed0060.png (deflated 0%)
#   adding: ANTHgenerated-images/seed0078.png (deflated 0%)
#   adding: ANTHgenerated-images/seed0071.png (deflated 0%)
#   adding: ANTHgenerated-images/seed0075.png (deflated 1%)
#   adding: ANTHgenerated-images/seed0054.png (deflated 1%)
#   adding: ANTHgenerated-images/seed0099.png (deflated 0%)
#   adding: ANTHgenerated-images/seed0062.png (deflated 0%)
#   adding: ANTHgenerated-images/seed0050.png (deflated 0%)
#   adding: ANTHgenerated-images/seed0018.png (deflated 1%)
#   adding: ANTHgenerated-images/seed0083.png (deflated 1%)
#   adding: ANTHgenerated-images/seed0001.png (deflated 1%)
#   adding: ANTHgenerated-images/seed0035.png (deflated 0%)
#   adding: ANTHgenerated-images/seed0013.png (deflated 0%)
#   adding: ANTHgenerated-images/seed0020.png (deflated 0%)
#   adding: ANTHgenerated-images/seed0037.png (deflated 1%)
#   adding: ANTHgenerated-images/seed0025.png (deflated 0%)
#   adding: ANTHgenerated-images/seed0036.png (deflated 1%)
#   adding: ANTHgenerated-images/seed0030.png (deflated 1%)
#   adding: ANTHgenerated-images/seed0047.png (deflated 1%)
#   adding: ANTHgenerated-images/seed0091.png (deflated 1%)
#   adding: ANTHgenerated-images/seed0085.png (deflated 1%)
#   adding: ANTHgenerated-images/seed0051.png (deflated 0%)
#   adding: ANTHgenerated-images/seed0022.png (deflated 0%)
#   adding: ANTHgenerated-images/seed0067.png (deflated 1%)
#   adding: ANTHgenerated-images/seed0004.png (deflated 0%)
#   adding: ANTHgenerated-images/seed0055.png (deflated 0%)
#   adding: ANTHgenerated-images/seed0079.png (deflated 1%)
#   adding: ANTHgenerated-images/seed0056.png (deflated 0%)
#   adding: ANTHgenerated-images/seed0015.png (deflated 1%)
#   adding: ANTHgenerated-images/seed0096.png (deflated 1%)
#   adding: ANTHgenerated-images/seed0092.png (deflated 1%)
#   adding: ANTHgenerated-images/seed0044.png (deflated 1%)
#   adding: ANTHgenerated-images/seed0027.png (deflated 0%)
#   adding: ANTHgenerated-images/seed0087.png (deflated 1%)
#   adding: ANTHgenerated-images/seed0017.png (deflated 1%)
#   adding: ANTHgenerated-images/seed0064.png (deflated 0%)
#   adding: ANTHgenerated-images/seed0098.png (deflated 1%)
#   adding: ANTHgenerated-images/seed0058.png (deflated 1%)

# %%
#GENERATING IMAGES
# !python gen_images.py \
  --outdir=generated-images \
  --trunc=0.7 \
  --seeds=0-99 \
  --network=/kaggle/working/stylegan3/training-runs/00002-stylegan3-t-MangoLeaf-gpus2-batch4-gamma8.2/network-snapshot-000300.pkl

# %%
#ziping generated image
# !zip -r generated-images4.zip generated-images

# %%
#RAN SUCCESSFULLY
# !python train.py \
  --outdir=training-runs \
  --data=MangoLeaf.zip \
  --gpus=1 \
  --batch=2 \
  --gamma=8.2 \
  --snap=1 \
  --cfg=stylegan3-t \
  --mirror=0 \
  --aug=noaug \
  --kimg=2 \
  --cbase=16384 --cmax=64 \
  --mbstd-group=1

# %%
#FOR 1024X1024 IMAGES
# !python train.py \
  --outdir=training-runs \
  --data=MangoLeaf1024.zip \
  --gpus=2 \
  --batch=2 \
  --gamma=8.2 \
  --snap=10 \
  --cfg=stylegan3-t \
  --mirror=0 \
  --aug=ada \
  --kimg=200 \
  --cbase=8192 --cmax=64 \
  --mbstd-group=1 \
  --metrics=none
