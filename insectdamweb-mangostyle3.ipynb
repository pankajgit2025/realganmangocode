# %%
# !pip install torch torchvision tqdm ninja click requests
# !pip install -r docs/requirements.txt
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.6.0+cu124)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (0.21.0+cu124)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (4.67.1)
# Requirement already satisfied: ninja in /usr/local/lib/python3.11/dist-packages (1.11.1.4)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (8.1.8)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (2.32.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torchvision) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision) (11.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests) (2025.4.26)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision) (2.4.1)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->torchvision) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->torchvision) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy->torchvision) (1.3.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy->torchvision) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy->torchvision) (2024.2.0)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.1 MB/s eta 0:00:000:00:0100:01
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.1 MB/s eta 0:00:000:00:0100:01
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 8.3 MB/s eta 0:00:000:00:0100:01
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 27.5 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 12.5 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 7.8 MB/s eta 0:00:000:00:0100:01
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 63.0 MB/s eta 0:00:00:00:0100:01
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.9.41
#     Uninstalling nvidia-nvjitlink-cu12-12.9.41:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.9.41
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.10.19
#     Uninstalling nvidia-curand-cu12-10.3.10.19:
#       Successfully uninstalled nvidia-curand-cu12-10.3.10.19
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.4.0.6
#     Uninstalling nvidia-cufft-cu12-11.4.0.6:
#       Successfully uninstalled nvidia-cufft-cu12-11.4.0.6
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.9.0.13
#     Uninstalling nvidia-cublas-cu12-12.9.0.13:
#       Successfully uninstalled nvidia-cublas-cu12-12.9.0.13
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.9.5
#     Uninstalling nvidia-cusparse-cu12-12.5.9.5:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.9.5
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.7.4.40
#     Uninstalling nvidia-cusolver-cu12-11.7.4.40:
#       Successfully uninstalled nvidia-cusolver-cu12-11.7.4.40
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'docs/requirements.txt'

# %%
# !pip install opencv-python

# %%
# !git clone https://github.com/NVlabs/stylegan3.git
# Out:
# Cloning into 'stylegan3'...
# remote: Enumerating objects: 212, done.
# remote: Counting objects: 100% (163/163), done.
# remote: Compressing objects: 100% (73/73), done.
# remote: Total 212 (delta 99), reused 90 (delta 90), pack-reused 49 (from 1)
# Receiving objects: 100% (212/212), 4.16 MiB | 21.20 MiB/s, done.
# Resolving deltas: 100% (108/108), done.

# %%
# %cd stylegan3
# Out:
# /kaggle/working/stylegan3

# %%
# !pip install torch torchvision
# !pip install numpy scipy pillow requests tqdm pyspng ninja
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.6.0+cu124)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (0.21.0+cu124)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torchvision) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision) (11.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision) (2.4.1)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->torchvision) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->torchvision) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy->torchvision) (1.3.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy->torchvision) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy->torchvision) (2024.2.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (1.15.2)
# Requirement already satisfied: pillow in /usr/local/lib/python3.11/dist-packages (11.1.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (4.67.1)
# Collecting pyspng
#   Downloading pyspng-0.1.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.0 kB)
# Requirement already satisfied: ninja in /usr/local/lib/python3.11/dist-packages (1.11.1.4)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy) (2.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests) (2025.4.26)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy) (1.3.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy) (2024.2.0)
# Downloading pyspng-0.1.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (196 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.1/196.1 kB 4.3 MB/s eta 0:00:0000:01
# Installing collected packages: pyspng
# Successfully installed pyspng-0.1.3

# %%
# !pip install click dnnlib

# %%
# !pip install torch==2.0.1 torchvision==0.15.2
# Out:
# Collecting torch==2.0.1
#   Downloading torch-2.0.1-cp311-cp311-manylinux1_x86_64.whl.metadata (24 kB)
# Collecting torchvision==0.15.2
#   Downloading torchvision-0.15.2-cp311-cp311-manylinux1_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch==2.0.1) (3.18.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.11/dist-packages (from torch==2.0.1) (4.13.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/dist-packages (from torch==2.0.1) (1.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch==2.0.1) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch==2.0.1) (3.1.6)
# Collecting nvidia-cuda-nvrtc-cu11==11.7.99 (from torch==2.0.1)
#   Downloading nvidia_cuda_nvrtc_cu11-11.7.99-2-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu11==11.7.99 (from torch==2.0.1)
#   Downloading nvidia_cuda_runtime_cu11-11.7.99-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cuda-cupti-cu11==11.7.101 (from torch==2.0.1)
#   Downloading nvidia_cuda_cupti_cu11-11.7.101-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu11==8.5.0.96 (from torch==2.0.1)
#   Downloading nvidia_cudnn_cu11-8.5.0.96-2-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu11==11.10.3.66 (from torch==2.0.1)
#   Downloading nvidia_cublas_cu11-11.10.3.66-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cufft-cu11==10.9.0.58 (from torch==2.0.1)
#   Downloading nvidia_cufft_cu11-10.9.0.58-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu11==10.2.10.91 (from torch==2.0.1)
#   Downloading nvidia_curand_cu11-10.2.10.91-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusolver-cu11==11.4.0.1 (from torch==2.0.1)
#   Downloading nvidia_cusolver_cu11-11.4.0.1-2-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu11==11.7.4.91 (from torch==2.0.1)
#   Downloading nvidia_cusparse_cu11-11.7.4.91-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu11==2.14.3 (from torch==2.0.1)
#   Downloading nvidia_nccl_cu11-2.14.3-py3-none-manylinux1_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu11==11.7.91 (from torch==2.0.1)
#   Downloading nvidia_nvtx_cu11-11.7.91-py3-none-manylinux1_x86_64.whl.metadata (1.7 kB)
# Collecting triton==2.0.0 (from torch==2.0.1)
#   Downloading triton-2.0.0-1-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.0 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torchvision==0.15.2) (1.26.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from torchvision==0.15.2) (2.32.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision==0.15.2) (11.1.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch==2.0.1) (75.2.0)
# Requirement already satisfied: wheel in /usr/local/lib/python3.11/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch==2.0.1) (0.45.1)
# Requirement already satisfied: cmake in /usr/local/lib/python3.11/dist-packages (from triton==2.0.0->torch==2.0.1) (3.31.6)
# Collecting lit (from triton==2.0.0->torch==2.0.1)
#   Downloading lit-18.1.8-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch==2.0.1) (3.0.2)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision==0.15.2) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision==0.15.2) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision==0.15.2) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision==0.15.2) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision==0.15.2) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision==0.15.2) (2.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->torchvision==0.15.2) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->torchvision==0.15.2) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->torchvision==0.15.2) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->torchvision==0.15.2) (2025.4.26)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy->torch==2.0.1) (1.3.0)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->torchvision==0.15.2) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->torchvision==0.15.2) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy->torchvision==0.15.2) (1.3.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy->torchvision==0.15.2) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy->torchvision==0.15.2) (2024.2.0)
# Downloading torch-2.0.1-cp311-cp311-manylinux1_x86_64.whl (619.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 619.9/619.9 MB 2.5 MB/s eta 0:00:000:00:0100:01
# Downloading torchvision-0.15.2-cp311-cp311-manylinux1_x86_64.whl (6.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 80.4 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cublas_cu11-11.10.3.66-py3-none-manylinux1_x86_64.whl (317.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.1/317.1 MB 2.3 MB/s eta 0:00:000:00:0100:01
# Downloading nvidia_cuda_cupti_cu11-11.7.101-py3-none-manylinux1_x86_64.whl (11.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 71.0 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cuda_nvrtc_cu11-11.7.99-2-py3-none-manylinux1_x86_64.whl (21.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.0/21.0 MB 54.8 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cuda_runtime_cu11-11.7.99-py3-none-manylinux1_x86_64.whl (849 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.3/849.3 kB 29.2 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu11-8.5.0.96-2-py3-none-manylinux1_x86_64.whl (557.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 557.1/557.1 MB 2.9 MB/s eta 0:00:000:00:0100:01
# Downloading nvidia_cufft_cu11-10.9.0.58-py3-none-manylinux2014_x86_64.whl (168.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.4/168.4 MB 9.6 MB/s eta 0:00:000:00:0100:01
# Downloading nvidia_curand_cu11-10.2.10.91-py3-none-manylinux1_x86_64.whl (54.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.6/54.6 MB 28.1 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cusolver_cu11-11.4.0.1-2-py3-none-manylinux1_x86_64.whl (102.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.6/102.6 MB 14.7 MB/s eta 0:00:00:00:010:01
# Downloading nvidia_cusparse_cu11-11.7.4.91-py3-none-manylinux1_x86_64.whl (173.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 173.2/173.2 MB 9.3 MB/s eta 0:00:000:00:0100:01
# Downloading nvidia_nccl_cu11-2.14.3-py3-none-manylinux1_x86_64.whl (177.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.1/177.1 MB 8.9 MB/s eta 0:00:000:00:0100:01
# Downloading nvidia_nvtx_cu11-11.7.91-py3-none-manylinux1_x86_64.whl (98 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.6/98.6 kB 106.5 kB/s eta 0:00:00a 0:00:01
# Downloading triton-2.0.0-1-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (63.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.3/63.3 MB 25.2 MB/s eta 0:00:00:00:0100:01
# Downloading lit-18.1.8-py3-none-any.whl (96 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.4/96.4 kB 5.4 MB/s eta 0:00:00
# Installing collected packages: lit, nvidia-nvtx-cu11, nvidia-nccl-cu11, nvidia-cusparse-cu11, nvidia-curand-cu11, nvidia-cufft-cu11, nvidia-cuda-runtime-cu11, nvidia-cuda-nvrtc-cu11, nvidia-cuda-cupti-cu11, nvidia-cublas-cu11, nvidia-cusolver-cu11, nvidia-cudnn-cu11, triton, torch, torchvision
#   Attempting uninstall: triton
#     Found existing installation: triton 3.2.0
#     Uninstalling triton-3.2.0:
#       Successfully uninstalled triton-3.2.0
#   Attempting uninstall: torch
#     Found existing installation: torch 2.6.0+cu124
#     Uninstalling torch-2.6.0+cu124:
#       Successfully uninstalled torch-2.6.0+cu124
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.21.0+cu124
#     Uninstalling torchvision-0.21.0+cu124:
#       Successfully uninstalled torchvision-0.21.0+cu124
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pytorch-lightning 2.5.1.post0 requires torch>=2.1.0, but you have torch 2.0.1 which is incompatible.
# torchaudio 2.6.0+cu124 requires torch==2.6.0, but you have torch 2.0.1 which is incompatible.
# Successfully installed lit-18.1.8 nvidia-cublas-cu11-11.10.3.66 nvidia-cuda-cupti-cu11-11.7.101 nvidia-cuda-nvrtc-cu11-11.7.99 nvidia-cuda-runtime-cu11-11.7.99 nvidia-cudnn-cu11-8.5.0.96 nvidia-cufft-cu11-10.9.0.58 nvidia-curand-cu11-10.2.10.91 nvidia-cusolver-cu11-11.4.0.1 nvidia-cusparse-cu11-11.7.4.91 nvidia-nccl-cu11-2.14.3 nvidia-nvtx-cu11-11.7.91 torch-2.0.1 torchvision-0.15.2 triton-2.0.0

# %%
# !pip install ninja pyspng click requests tqdm

# %%
# !wget --content-disposition 'https://api.ngc.nvidia.com/v2/models/org/nvidia/team/research/stylegan3/1/files?redirect=true&path=stylegan3-t-afhqv2-512x512.pkl' -O stylegan3-t-afhqv2-512x512.pkl

# %%
# !python dataset_tool.py --source="/kaggle/input/inswebber512x512/INSECT DAMAGE WEBBER" --dest=INSECTDAMAGE.zip
# Out:
# 100%|███████████████████████████████████████| 1136/1136 [00:32<00:00, 34.52it/s]

# %%
ls /kaggle/working/*
# Out:
# avg_spectra.py   Dockerfile       gen_video.py      LICENSE.txt   training/
# calc_metrics.py  docs/            gui_utils/        metrics/      train.py
# dataset_tool.py  environment.yml  INSECTDAMAGE.zip  README.md     visualizer.py
# dnnlib/          gen_images.py    legacy.py         torch_utils/  viz/

# %%
# !python train.py \
  --outdir=training-runs \
  --data=INSECTDAMAGE.zip \
  --gpus=2 \
  --batch=4 \
  --gamma=8.2 \
  --snap=10 \
  --cfg=stylegan3-t \
  --mirror=0 \
  --aug=ada \
  --kimg=120 \
  --cbase=16384 --cmax=64 \
  --mbstd-group=2 \
  --metrics=none
# Out:
# Training options:
# {
#   "G_kwargs": {
#     "class_name": "training.networks_stylegan3.Generator",
#     "z_dim": 512,
#     "w_dim": 512,
#     "mapping_kwargs": {
#       "num_layers": 2
#     },
#     "channel_base": 16384,
#     "channel_max": 64,
#     "magnitude_ema_beta": 0.9998613801725043
#   },
#   "D_kwargs": {
#     "class_name": "training.networks_stylegan2.Discriminator",
#     "block_kwargs": {
#       "freeze_layers": 0
#     },
#     "mapping_kwargs": {},
#     "epilogue_kwargs": {
#       "mbstd_group_size": 2
#     },
#     "channel_base": 16384,
#     "channel_max": 64
#   },
#   "G_opt_kwargs": {
#     "class_name": "torch.optim.Adam",
#     "betas": [
#       0,
#       0.99
#     ],
#     "eps": 1e-08,
#     "lr": 0.0025
#   },
#   "D_opt_kwargs": {
#     "class_name": "torch.optim.Adam",
#     "betas": [
#       0,
#       0.99
#     ],
#     "eps": 1e-08,
#     "lr": 0.002
#   },
#   "loss_kwargs": {
#     "class_name": "training.loss.StyleGAN2Loss",
#     "r1_gamma": 8.2
#   },
#   "data_loader_kwargs": {
#     "pin_memory": true,
#     "prefetch_factor": 2,
#     "num_workers": 3
#   },
#   "training_set_kwargs": {
#     "class_name": "training.dataset.ImageFolderDataset",
#     "path": "INSECTDAMAGE.zip",
#     "use_labels": false,
#     "max_size": 1136,
#     "xflip": false,
#     "resolution": 512,
#     "random_seed": 0
#   },
#   "num_gpus": 2,
#   "batch_size": 4,
#   "batch_gpu": 2,
#   "metrics": [],
#   "total_kimg": 120,
#   "kimg_per_tick": 4,
#   "image_snapshot_ticks": 10,
#   "network_snapshot_ticks": 10,
#   "random_seed": 0,
#   "ema_kimg": 1.25,
#   "augment_kwargs": {
#     "class_name": "training.augment.AugmentPipe",
#     "xflip": 1,
#     "rotate90": 1,
#     "xint": 1,
#     "scale": 1,
#     "rotate": 1,
#     "aniso": 1,
#     "xfrac": 1,
#     "brightness": 1,
#     "contrast": 1,
#     "lumaflip": 1,
#     "hue": 1,
#     "saturation": 1
#   },
#   "ada_target": 0.6,
#   "run_dir": "training-runs/00000-stylegan3-t-INSECTDAMAGE-gpus2-batch4-gamma8.2"
# }
#
# Output directory:    training-runs/00000-stylegan3-t-INSECTDAMAGE-gpus2-batch4-gamma8.2
# Number of GPUs:      2
# Batch size:          4 images
# Training duration:   120 kimg
# Dataset path:        INSECTDAMAGE.zip
# Dataset size:        1136 images
# Dataset resolution:  512
# Dataset labels:      False
# Dataset x-flips:     False
#
# Creating output directory...
# Launching processes...
# Loading training set...
#
# Num images:  1136
# Image shape: [3, 512, 512]
# Label shape: [0]
#
# Constructing networks...
# Setting up PyTorch plugin "bias_act_plugin"... Done.
# Setting up PyTorch plugin "filtered_lrelu_plugin"... Done.
#
# Generator                    Parameters  Buffers  Output shape       Datatype
# ---                          ---         ---      ---                ---
# mapping.fc0                  262656      -        [2, 512]           float32
# mapping.fc1                  262656      -        [2, 512]           float32
# mapping                      -           512      [2, 16, 512]       float32
# synthesis.input.affine       2052        -        [2, 4]             float32
# synthesis.input              4096        201      [2, 64, 36, 36]    float32
# synthesis.L0_36_64.affine    32832       -        [2, 64]            float32
# synthesis.L0_36_64           36928       25       [2, 64, 36, 36]    float32
# synthesis.L1_36_64.affine    32832       -        [2, 64]            float32
# synthesis.L1_36_64           36928       25       [2, 64, 36, 36]    float32
# synthesis.L2_52_64.affine    32832       -        [2, 64]            float32
# synthesis.L2_52_64           36928       37       [2, 64, 52, 52]    float32
# synthesis.L3_52_64.affine    32832       -        [2, 64]            float32
# synthesis.L3_52_64           36928       25       [2, 64, 52, 52]    float32
# synthesis.L4_84_64.affine    32832       -        [2, 64]            float32
# synthesis.L4_84_64           36928       37       [2, 64, 84, 84]    float16
# synthesis.L5_84_64.affine    32832       -        [2, 64]            float32
# synthesis.L5_84_64           36928       25       [2, 64, 84, 84]    float16
# synthesis.L6_148_64.affine   32832       -        [2, 64]            float32
# synthesis.L6_148_64          36928       37       [2, 64, 148, 148]  float16
# synthesis.L7_148_64.affine   32832       -        [2, 64]            float32
# synthesis.L7_148_64          36928       25       [2, 64, 148, 148]  float16
# synthesis.L8_276_64.affine   32832       -        [2, 64]            float32
# synthesis.L8_276_64          36928       37       [2, 64, 276, 276]  float16
# synthesis.L9_276_64.affine   32832       -        [2, 64]            float32
# synthesis.L9_276_64          36928       25       [2, 64, 276, 276]  float16
# synthesis.L10_532_64.affine  32832       -        [2, 64]            float32
# synthesis.L10_532_64         36928       37       [2, 64, 532, 532]  float16
# synthesis.L11_532_48.affine  32832       -        [2, 64]            float32
# synthesis.L11_532_48         27696       25       [2, 48, 532, 532]  float16
# synthesis.L12_532_32.affine  24624       -        [2, 48]            float32
# synthesis.L12_532_32         13856       25       [2, 32, 532, 532]  float16
# synthesis.L13_512_32.affine  16416       -        [2, 32]            float32
# synthesis.L13_512_32         9248        25       [2, 32, 512, 512]  float16
# synthesis.L14_512_3.affine   16416       -        [2, 32]            float32
# synthesis.L14_512_3          99          1        [2, 3, 512, 512]   float16
# synthesis                    -           -        [2, 3, 512, 512]   float32
# ---                          ---         ---      ---                ---
# Total                        1440007     1124     -                  -
#
# Setting up PyTorch plugin "upfirdn2d_plugin"... Done.
#
# Discriminator  Parameters  Buffers  Output shape       Datatype
# ---            ---         ---      ---                ---
# b512.fromrgb   128         16       [2, 32, 512, 512]  float16
# b512.skip      2048        16       [2, 64, 256, 256]  float16
# b512.conv0     9248        16       [2, 32, 512, 512]  float16
# b512.conv1     18496       16       [2, 64, 256, 256]  float16
# b512           -           16       [2, 64, 256, 256]  float16
# b256.skip      4096        16       [2, 64, 128, 128]  float16
# b256.conv0     36928       16       [2, 64, 256, 256]  float16
# b256.conv1     36928       16       [2, 64, 128, 128]  float16
# b256           -           16       [2, 64, 128, 128]  float16
# b128.skip      4096        16       [2, 64, 64, 64]    float16
# b128.conv0     36928       16       [2, 64, 128, 128]  float16
# b128.conv1     36928       16       [2, 64, 64, 64]    float16
# b128           -           16       [2, 64, 64, 64]    float16
# b64.skip       4096        16       [2, 64, 32, 32]    float16
# b64.conv0      36928       16       [2, 64, 64, 64]    float16
# b64.conv1      36928       16       [2, 64, 32, 32]    float16
# b64            -           16       [2, 64, 32, 32]    float16
# b32.skip       4096        16       [2, 64, 16, 16]    float32
# b32.conv0      36928       16       [2, 64, 32, 32]    float32
# b32.conv1      36928       16       [2, 64, 16, 16]    float32
# b32            -           16       [2, 64, 16, 16]    float32
# b16.skip       4096        16       [2, 64, 8, 8]      float32
# b16.conv0      36928       16       [2, 64, 16, 16]    float32
# b16.conv1      36928       16       [2, 64, 8, 8]      float32
# b16            -           16       [2, 64, 8, 8]      float32
# b8.skip        4096        16       [2, 64, 4, 4]      float32
# b8.conv0       36928       16       [2, 64, 8, 8]      float32
# b8.conv1       36928       16       [2, 64, 4, 4]      float32
# b8             -           16       [2, 64, 4, 4]      float32
# b4.mbstd       -           -        [2, 65, 4, 4]      float32
# b4.conv        37504       16       [2, 64, 4, 4]      float32
# b4.fc          65600       -        [2, 64]            float32
# b4.out         65          -        [2, 1]             float32
# ---            ---         ---      ---                ---
# Total          600801      480      -                  -
#
# Setting up augmentation...
# Distributing across 2 GPUs...
# Setting up training phases...
# Exporting sample images...
# Initializing logs...
# 2025-05-29 17:11:52.634624: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1748538713.214384     160 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1748538713.348958     160 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Training for 120 kimg...
#
# tick 0     kimg 0.0      time 3m 39s       sec/tick 8.9     sec/kimg 2215.51 maintenance 210.3  cpumem 3.95   gpumem 8.87   reserved 9.18   augment 0.000
# tick 1     kimg 4.0      time 8m 37s       sec/tick 289.2   sec/kimg 72.31   maintenance 8.4    cpumem 3.97   gpumem 0.72   reserved 0.96   augment 0.002
# tick 2     kimg 8.0      time 13m 25s      sec/tick 288.3   sec/kimg 72.07   maintenance 0.0    cpumem 3.97   gpumem 0.72   reserved 0.96   augment 0.004
# tick 3     kimg 12.0     time 18m 13s      sec/tick 287.4   sec/kimg 71.84   maintenance 0.1    cpumem 3.97   gpumem 0.72   reserved 0.96   augment 0.009
# tick 4     kimg 16.0     time 23m 00s      sec/tick 287.8   sec/kimg 71.94   maintenance 0.0    cpumem 3.97   gpumem 0.72   reserved 0.96   augment 0.015
# tick 5     kimg 20.0     time 27m 49s      sec/tick 288.3   sec/kimg 72.07   maintenance 0.1    cpumem 3.97   gpumem 0.72   reserved 0.96   augment 0.022
# tick 6     kimg 24.0     time 32m 38s      sec/tick 289.1   sec/kimg 72.27   maintenance 0.0    cpumem 3.97   gpumem 0.73   reserved 0.96   augment 0.027
# tick 7     kimg 28.0     time 37m 28s      sec/tick 289.8   sec/kimg 72.44   maintenance 0.1    cpumem 3.97   gpumem 0.72   reserved 0.96   augment 0.032
# tick 8     kimg 32.0     time 42m 18s      sec/tick 289.8   sec/kimg 72.45   maintenance 0.0    cpumem 3.97   gpumem 0.75   reserved 0.96   augment 0.036
# tick 9     kimg 36.0     time 47m 07s      sec/tick 289.4   sec/kimg 72.36   maintenance 0.1    cpumem 3.97   gpumem 0.73   reserved 0.96   augment 0.040
# tick 10    kimg 40.0     time 51m 57s      sec/tick 289.7   sec/kimg 72.43   maintenance 0.0    cpumem 3.97   gpumem 0.73   reserved 0.97   augment 0.043
# tick 11    kimg 44.0     time 57m 05s      sec/tick 291.8   sec/kimg 72.95   maintenance 16.0   cpumem 3.98   gpumem 0.72   reserved 0.97   augment 0.044
# tick 12    kimg 48.0     time 1h 01m 55s   sec/tick 290.4   sec/kimg 72.61   maintenance 0.0    cpumem 3.98   gpumem 0.73   reserved 0.97   augment 0.046
# tick 13    kimg 52.0     time 1h 06m 45s   sec/tick 289.6   sec/kimg 72.40   maintenance 0.1    cpumem 3.98   gpumem 0.73   reserved 0.97   augment 0.048
# tick 14    kimg 56.0     time 1h 11m 35s   sec/tick 290.0   sec/kimg 72.50   maintenance 0.0    cpumem 3.98   gpumem 0.73   reserved 0.97   augment 0.048
# tick 15    kimg 60.0     time 1h 16m 25s   sec/tick 289.8   sec/kimg 72.45   maintenance 0.1    cpumem 3.98   gpumem 0.77   reserved 0.97   augment 0.049
# tick 16    kimg 64.0     time 1h 21m 15s   sec/tick 290.1   sec/kimg 72.52   maintenance 0.0    cpumem 3.98   gpumem 0.73   reserved 0.97   augment 0.049
# tick 17    kimg 68.0     time 1h 26m 05s   sec/tick 290.1   sec/kimg 72.52   maintenance 0.1    cpumem 3.98   gpumem 0.74   reserved 0.97   augment 0.049
# tick 18    kimg 72.0     time 1h 30m 56s   sec/tick 290.9   sec/kimg 72.72   maintenance 0.0    cpumem 3.98   gpumem 0.74   reserved 0.97   augment 0.052
# tick 19    kimg 76.0     time 1h 35m 47s   sec/tick 290.9   sec/kimg 72.74   maintenance 0.1    cpumem 3.98   gpumem 0.74   reserved 0.97   augment 0.054
# tick 20    kimg 80.0     time 1h 40m 38s   sec/tick 290.7   sec/kimg 72.66   maintenance 0.0    cpumem 3.98   gpumem 0.74   reserved 0.97   augment 0.057
# tick 21    kimg 84.0     time 1h 45m 45s   sec/tick 292.3   sec/kimg 73.08   maintenance 14.7   cpumem 4.32   gpumem 0.73   reserved 0.97   augment 0.060
# tick 22    kimg 88.0     time 1h 50m 35s   sec/tick 290.3   sec/kimg 72.57   maintenance 0.0    cpumem 4.32   gpumem 0.74   reserved 0.97   augment 0.059
# tick 23    kimg 92.0     time 1h 55m 26s   sec/tick 290.7   sec/kimg 72.68   maintenance 0.1    cpumem 4.32   gpumem 0.76   reserved 0.97   augment 0.055
# tick 24    kimg 96.0     time 2h 00m 17s   sec/tick 290.7   sec/kimg 72.67   maintenance 0.0    cpumem 4.32   gpumem 0.74   reserved 0.97   augment 0.050
# tick 25    kimg 100.0    time 2h 05m 08s   sec/tick 290.6   sec/kimg 72.66   maintenance 0.1    cpumem 4.32   gpumem 0.75   reserved 0.97   augment 0.045
# tick 26    kimg 104.0    time 2h 09m 58s   sec/tick 290.1   sec/kimg 72.53   maintenance 0.0    cpumem 4.32   gpumem 0.75   reserved 0.97   augment 0.040
# tick 27    kimg 108.0    time 2h 14m 48s   sec/tick 290.2   sec/kimg 72.55   maintenance 0.1    cpumem 4.32   gpumem 0.73   reserved 0.97   augment 0.036
# tick 28    kimg 112.0    time 2h 19m 38s   sec/tick 289.9   sec/kimg 72.47   maintenance 0.0    cpumem 4.32   gpumem 0.75   reserved 0.97   augment 0.032
# tick 29    kimg 116.0    time 2h 24m 28s   sec/tick 290.1   sec/kimg 72.53   maintenance 0.1    cpumem 4.32   gpumem 0.75   reserved 0.97   augment 0.028
# tick 30    kimg 120.0    time 2h 29m 18s   sec/tick 290.2   sec/kimg 72.61   maintenance 0.0    cpumem 4.32   gpumem 0.73   reserved 0.97   augment 0.026
#
# Exiting...

# %%
# !python train.py \
  --outdir=training-runs \
  --data=INSECTDAMAGE.zip \
  --gpus=2 \
  --batch=4 \
  --gamma=8.2 \
  --snap=10 \
  --cfg=stylegan3-t \
  --mirror=1 \
  --aug=ada \
  --kimg=600 \
  --cbase=16384 --cmax=64 \
  --mbstd-group=2 \
  --metrics=none \
  --resume=/kaggle/working/stylegan3/training-runs/00000-stylegan3-t-INSECTDAMAGE-gpus2-batch4-gamma8.2/network-snapshot-000120.pkl
# Out:
# Training options:
# {
#   "G_kwargs": {
#     "class_name": "training.networks_stylegan3.Generator",
#     "z_dim": 512,
#     "w_dim": 512,
#     "mapping_kwargs": {
#       "num_layers": 2
#     },
#     "channel_base": 16384,
#     "channel_max": 64,
#     "magnitude_ema_beta": 0.9998613801725043
#   },
#   "D_kwargs": {
#     "class_name": "training.networks_stylegan2.Discriminator",
#     "block_kwargs": {
#       "freeze_layers": 0
#     },
#     "mapping_kwargs": {},
#     "epilogue_kwargs": {
#       "mbstd_group_size": 2
#     },
#     "channel_base": 16384,
#     "channel_max": 64
#   },
#   "G_opt_kwargs": {
#     "class_name": "torch.optim.Adam",
#     "betas": [
#       0,
#       0.99
#     ],
#     "eps": 1e-08,
#     "lr": 0.0025
#   },
#   "D_opt_kwargs": {
#     "class_name": "torch.optim.Adam",
#     "betas": [
#       0,
#       0.99
#     ],
#     "eps": 1e-08,
#     "lr": 0.002
#   },
#   "loss_kwargs": {
#     "class_name": "training.loss.StyleGAN2Loss",
#     "r1_gamma": 8.2,
#     "blur_init_sigma": 0
#   },
#   "data_loader_kwargs": {
#     "pin_memory": true,
#     "prefetch_factor": 2,
#     "num_workers": 3
#   },
#   "training_set_kwargs": {
#     "class_name": "training.dataset.ImageFolderDataset",
#     "path": "INSECTDAMAGE.zip",
#     "use_labels": false,
#     "max_size": 1136,
#     "xflip": true,
#     "resolution": 512,
#     "random_seed": 0
#   },
#   "num_gpus": 2,
#   "batch_size": 4,
#   "batch_gpu": 2,
#   "metrics": [],
#   "total_kimg": 600,
#   "kimg_per_tick": 4,
#   "image_snapshot_ticks": 10,
#   "network_snapshot_ticks": 10,
#   "random_seed": 0,
#   "ema_kimg": 1.25,
#   "augment_kwargs": {
#     "class_name": "training.augment.AugmentPipe",
#     "xflip": 1,
#     "rotate90": 1,
#     "xint": 1,
#     "scale": 1,
#     "rotate": 1,
#     "aniso": 1,
#     "xfrac": 1,
#     "brightness": 1,
#     "contrast": 1,
#     "lumaflip": 1,
#     "hue": 1,
#     "saturation": 1
#   },
#   "ada_target": 0.6,
#   "resume_pkl": "/kaggle/working/stylegan3/training-runs/00000-stylegan3-t-INSECTDAMAGE-gpus2-batch4-gamma8.2/network-snapshot-000120.pkl",
#   "ada_kimg": 100,
#   "ema_rampup": null,
#   "run_dir": "training-runs/00001-stylegan3-t-INSECTDAMAGE-gpus2-batch4-gamma8.2"
# }
#
# Output directory:    training-runs/00001-stylegan3-t-INSECTDAMAGE-gpus2-batch4-gamma8.2
# Number of GPUs:      2
# Batch size:          4 images
# Training duration:   600 kimg
# Dataset path:        INSECTDAMAGE.zip
# Dataset size:        1136 images
# Dataset resolution:  512
# Dataset labels:      False
# Dataset x-flips:     True
#
# Creating output directory...
# Launching processes...
# Loading training set...
#
# Num images:  2272
# Image shape: [3, 512, 512]
# Label shape: [0]
#
# Constructing networks...
# Resuming from "/kaggle/working/stylegan3/training-runs/00000-stylegan3-t-INSECTDAMAGE-gpus2-batch4-gamma8.2/network-snapshot-000120.pkl"
# Setting up PyTorch plugin "bias_act_plugin"... Done.
# Setting up PyTorch plugin "filtered_lrelu_plugin"... Done.
#
# Generator                    Parameters  Buffers  Output shape       Datatype
# ---                          ---         ---      ---                ---
# mapping.fc0                  262656      -        [2, 512]           float32
# mapping.fc1                  262656      -        [2, 512]           float32
# mapping                      -           512      [2, 16, 512]       float32
# synthesis.input.affine       2052        -        [2, 4]             float32
# synthesis.input              4096        201      [2, 64, 36, 36]    float32
# synthesis.L0_36_64.affine    32832       -        [2, 64]            float32
# synthesis.L0_36_64           36928       25       [2, 64, 36, 36]    float32
# synthesis.L1_36_64.affine    32832       -        [2, 64]            float32
# synthesis.L1_36_64           36928       25       [2, 64, 36, 36]    float32
# synthesis.L2_52_64.affine    32832       -        [2, 64]            float32
# synthesis.L2_52_64           36928       37       [2, 64, 52, 52]    float32
# synthesis.L3_52_64.affine    32832       -        [2, 64]            float32
# synthesis.L3_52_64           36928       25       [2, 64, 52, 52]    float32
# synthesis.L4_84_64.affine    32832       -        [2, 64]            float32
# synthesis.L4_84_64           36928       37       [2, 64, 84, 84]    float16
# synthesis.L5_84_64.affine    32832       -        [2, 64]            float32
# synthesis.L5_84_64           36928       25       [2, 64, 84, 84]    float16
# synthesis.L6_148_64.affine   32832       -        [2, 64]            float32
# synthesis.L6_148_64          36928       37       [2, 64, 148, 148]  float16
# synthesis.L7_148_64.affine   32832       -        [2, 64]            float32
# synthesis.L7_148_64          36928       25       [2, 64, 148, 148]  float16
# synthesis.L8_276_64.affine   32832       -        [2, 64]            float32
# synthesis.L8_276_64          36928       37       [2, 64, 276, 276]  float16
# synthesis.L9_276_64.affine   32832       -        [2, 64]            float32
# synthesis.L9_276_64          36928       25       [2, 64, 276, 276]  float16
# synthesis.L10_532_64.affine  32832       -        [2, 64]            float32
# synthesis.L10_532_64         36928       37       [2, 64, 532, 532]  float16
# synthesis.L11_532_48.affine  32832       -        [2, 64]            float32
# synthesis.L11_532_48         27696       25       [2, 48, 532, 532]  float16
# synthesis.L12_532_32.affine  24624       -        [2, 48]            float32
# synthesis.L12_532_32         13856       25       [2, 32, 532, 532]  float16
# synthesis.L13_512_32.affine  16416       -        [2, 32]            float32
# synthesis.L13_512_32         9248        25       [2, 32, 512, 512]  float16
# synthesis.L14_512_3.affine   16416       -        [2, 32]            float32
# synthesis.L14_512_3          99          1        [2, 3, 512, 512]   float16
# synthesis                    -           -        [2, 3, 512, 512]   float32
# ---                          ---         ---      ---                ---
# Total                        1440007     1124     -                  -
#
# Setting up PyTorch plugin "upfirdn2d_plugin"... Done.
#
# Discriminator  Parameters  Buffers  Output shape       Datatype
# ---            ---         ---      ---                ---
# b512.fromrgb   128         16       [2, 32, 512, 512]  float16
# b512.skip      2048        16       [2, 64, 256, 256]  float16
# b512.conv0     9248        16       [2, 32, 512, 512]  float16
# b512.conv1     18496       16       [2, 64, 256, 256]  float16
# b512           -           16       [2, 64, 256, 256]  float16
# b256.skip      4096        16       [2, 64, 128, 128]  float16
# b256.conv0     36928       16       [2, 64, 256, 256]  float16
# b256.conv1     36928       16       [2, 64, 128, 128]  float16
# b256           -           16       [2, 64, 128, 128]  float16
# b128.skip      4096        16       [2, 64, 64, 64]    float16
# b128.conv0     36928       16       [2, 64, 128, 128]  float16
# b128.conv1     36928       16       [2, 64, 64, 64]    float16
# b128           -           16       [2, 64, 64, 64]    float16
# b64.skip       4096        16       [2, 64, 32, 32]    float16
# b64.conv0      36928       16       [2, 64, 64, 64]    float16
# b64.conv1      36928       16       [2, 64, 32, 32]    float16
# b64            -           16       [2, 64, 32, 32]    float16
# b32.skip       4096        16       [2, 64, 16, 16]    float32
# b32.conv0      36928       16       [2, 64, 32, 32]    float32
# b32.conv1      36928       16       [2, 64, 16, 16]    float32
# b32            -           16       [2, 64, 16, 16]    float32
# b16.skip       4096        16       [2, 64, 8, 8]      float32
# b16.conv0      36928       16       [2, 64, 16, 16]    float32
# b16.conv1      36928       16       [2, 64, 8, 8]      float32
# b16            -           16       [2, 64, 8, 8]      float32
# b8.skip        4096        16       [2, 64, 4, 4]      float32
# b8.conv0       36928       16       [2, 64, 8, 8]      float32
# b8.conv1       36928       16       [2, 64, 4, 4]      float32
# b8             -           16       [2, 64, 4, 4]      float32
# b4.mbstd       -           -        [2, 65, 4, 4]      float32
# b4.conv        37504       16       [2, 64, 4, 4]      float32
# b4.fc          65600       -        [2, 64]            float32
# b4.out         65          -        [2, 1]             float32
# ---            ---         ---      ---                ---
# Total          600801      480      -                  -
#
# Setting up augmentation...
# Distributing across 2 GPUs...
# Setting up training phases...
# Exporting sample images...
# Initializing logs...
# 2025-05-29 19:42:49.380624: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1748547769.402460     486 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1748547769.410355     486 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Training for 600 kimg...
#
# tick 0     kimg 0.0      time 53s          sec/tick 8.7     sec/kimg 2165.98 maintenance 44.8   cpumem 4.11   gpumem 8.87   reserved 9.13   augment 0.000
# tick 1     kimg 4.0      time 6m 01s       sec/tick 293.1   sec/kimg 73.28   maintenance 14.8   cpumem 4.32   gpumem 0.70   reserved 0.92   augment 0.000
# tick 2     kimg 8.0      time 10m 53s      sec/tick 291.8   sec/kimg 72.96   maintenance 0.0    cpumem 4.32   gpumem 0.70   reserved 0.92   augment 0.000
# tick 3     kimg 12.0     time 15m 45s      sec/tick 291.6   sec/kimg 72.91   maintenance 0.1    cpumem 4.32   gpumem 0.70   reserved 0.92   augment 0.000
# tick 4     kimg 16.0     time 20m 38s      sec/tick 292.7   sec/kimg 73.19   maintenance 0.0    cpumem 4.32   gpumem 0.70   reserved 0.92   augment 0.001
# tick 5     kimg 20.0     time 25m 32s      sec/tick 294.5   sec/kimg 73.62   maintenance 0.1    cpumem 4.32   gpumem 0.70   reserved 0.92   augment 0.000
# tick 6     kimg 24.0     time 30m 26s      sec/tick 294.0   sec/kimg 73.50   maintenance 0.0    cpumem 4.32   gpumem 0.71   reserved 0.92   augment 0.000
# tick 7     kimg 28.0     time 35m 20s      sec/tick 293.6   sec/kimg 73.39   maintenance 0.1    cpumem 4.32   gpumem 0.71   reserved 0.92   augment 0.000
# tick 8     kimg 32.0     time 40m 13s      sec/tick 293.0   sec/kimg 73.24   maintenance 0.0    cpumem 4.32   gpumem 0.71   reserved 0.92   augment 0.001
# tick 9     kimg 36.0     time 45m 06s      sec/tick 292.8   sec/kimg 73.20   maintenance 0.1    cpumem 4.32   gpumem 0.71   reserved 0.92   augment 0.000
# tick 10    kimg 40.0     time 49m 58s      sec/tick 292.1   sec/kimg 73.03   maintenance 0.0    cpumem 4.32   gpumem 0.70   reserved 0.92   augment 0.000
# tick 11    kimg 44.0     time 55m 08s      sec/tick 294.4   sec/kimg 73.61   maintenance 15.4   cpumem 4.35   gpumem 0.72   reserved 0.92   augment 0.001
# tick 12    kimg 48.0     time 1h 00m 01s   sec/tick 292.5   sec/kimg 73.12   maintenance 0.0    cpumem 4.35   gpumem 0.72   reserved 0.92   augment 0.000
# tick 13    kimg 52.0     time 1h 04m 54s   sec/tick 292.9   sec/kimg 73.22   maintenance 0.1    cpumem 4.35   gpumem 0.71   reserved 0.92   augment 0.002
# tick 14    kimg 56.0     time 1h 09m 46s   sec/tick 292.8   sec/kimg 73.19   maintenance 0.0    cpumem 4.35   gpumem 0.72   reserved 0.92   augment 0.002
# tick 15    kimg 60.0     time 1h 14m 38s   sec/tick 292.0   sec/kimg 73.00   maintenance 0.1    cpumem 4.35   gpumem 0.72   reserved 0.92   augment 0.002
# tick 16    kimg 64.0     time 1h 19m 30s   sec/tick 291.7   sec/kimg 72.92   maintenance 0.0    cpumem 4.35   gpumem 0.72   reserved 0.92   augment 0.002
# tick 17    kimg 68.0     time 1h 24m 21s   sec/tick 291.1   sec/kimg 72.77   maintenance 0.1    cpumem 4.35   gpumem 0.72   reserved 0.92   augment 0.000
# tick 18    kimg 72.0     time 1h 29m 12s   sec/tick 290.9   sec/kimg 72.74   maintenance 0.0    cpumem 4.35   gpumem 0.72   reserved 0.92   augment 0.000
# tick 19    kimg 76.0     time 1h 34m 03s   sec/tick 290.8   sec/kimg 72.69   maintenance 0.1    cpumem 4.35   gpumem 0.71   reserved 0.92   augment 0.003
# tick 20    kimg 80.0     time 1h 38m 54s   sec/tick 290.5   sec/kimg 72.64   maintenance 0.0    cpumem 4.35   gpumem 0.72   reserved 0.92   augment 0.004
# tick 21    kimg 84.0     time 1h 44m 01s   sec/tick 292.9   sec/kimg 73.22   maintenance 14.7   cpumem 4.35   gpumem 0.72   reserved 0.92   augment 0.008
# tick 22    kimg 88.0     time 1h 48m 53s   sec/tick 291.6   sec/kimg 72.90   maintenance 0.0    cpumem 4.35   gpumem 0.72   reserved 0.92   augment 0.010
# tick 23    kimg 92.0     time 1h 53m 44s   sec/tick 291.1   sec/kimg 72.76   maintenance 0.1    cpumem 4.35   gpumem 0.75   reserved 0.92   augment 0.014
# tick 24    kimg 96.0     time 1h 58m 36s   sec/tick 291.7   sec/kimg 72.94   maintenance 0.0    cpumem 4.35   gpumem 0.72   reserved 0.92   augment 0.017
# tick 25    kimg 100.0    time 2h 03m 27s   sec/tick 291.4   sec/kimg 72.86   maintenance 0.1    cpumem 4.35   gpumem 0.72   reserved 0.92   augment 0.018
# tick 26    kimg 104.0    time 2h 08m 19s   sec/tick 291.3   sec/kimg 72.83   maintenance 0.0    cpumem 4.35   gpumem 0.72   reserved 0.92   augment 0.018
# tick 27    kimg 108.0    time 2h 13m 10s   sec/tick 290.7   sec/kimg 72.68   maintenance 0.1    cpumem 4.35   gpumem 0.73   reserved 0.92   augment 0.021
# tick 28    kimg 112.0    time 2h 18m 00s   sec/tick 290.3   sec/kimg 72.57   maintenance 0.0    cpumem 4.35   gpumem 0.74   reserved 0.92   augment 0.019
# tick 29    kimg 116.0    time 2h 22m 50s   sec/tick 290.3   sec/kimg 72.57   maintenance 0.1    cpumem 4.35   gpumem 0.72   reserved 0.92   augment 0.019
# tick 30    kimg 120.0    time 2h 27m 41s   sec/tick 290.8   sec/kimg 72.71   maintenance 0.0    cpumem 4.35   gpumem 0.72   reserved 0.92   augment 0.022
# tick 31    kimg 124.0    time 2h 32m 48s   sec/tick 292.1   sec/kimg 73.03   maintenance 14.8   cpumem 4.35   gpumem 0.72   reserved 0.92   augment 0.025
# tick 32    kimg 128.0    time 2h 37m 39s   sec/tick 291.0   sec/kimg 72.74   maintenance 0.0    cpumem 4.35   gpumem 0.72   reserved 0.92   augment 0.027
# tick 33    kimg 132.0    time 2h 42m 31s   sec/tick 291.6   sec/kimg 72.90   maintenance 0.1    cpumem 4.35   gpumem 0.73   reserved 0.92   augment 0.025
# tick 34    kimg 136.0    time 2h 47m 22s   sec/tick 291.2   sec/kimg 72.80   maintenance 0.0    cpumem 4.35   gpumem 0.72   reserved 0.92   augment 0.028
# tick 35    kimg 140.0    time 2h 52m 13s   sec/tick 291.0   sec/kimg 72.75   maintenance 0.1    cpumem 4.35   gpumem 0.73   reserved 0.92   augment 0.031
# tick 36    kimg 144.0    time 2h 57m 04s   sec/tick 290.9   sec/kimg 72.72   maintenance 0.0    cpumem 4.35   gpumem 0.72   reserved 0.92   augment 0.036
# tick 37    kimg 148.0    time 3h 01m 55s   sec/tick 290.8   sec/kimg 72.70   maintenance 0.1    cpumem 4.35   gpumem 0.72   reserved 0.92   augment 0.039
# tick 38    kimg 152.0    time 3h 06m 46s   sec/tick 291.4   sec/kimg 72.85   maintenance 0.0    cpumem 4.35   gpumem 0.72   reserved 0.92   augment 0.037
# tick 39    kimg 156.0    time 3h 11m 38s   sec/tick 291.5   sec/kimg 72.87   maintenance 0.1    cpumem 4.35   gpumem 0.73   reserved 0.92   augment 0.036
# tick 40    kimg 160.0    time 3h 16m 29s   sec/tick 291.3   sec/kimg 72.82   maintenance 0.0    cpumem 4.35   gpumem 0.73   reserved 0.92   augment 0.044
# tick 41    kimg 164.0    time 3h 21m 37s   sec/tick 292.7   sec/kimg 73.18   maintenance 14.8   cpumem 4.35   gpumem 0.73   reserved 0.92   augment 0.048
# tick 42    kimg 168.0    time 3h 26m 28s   sec/tick 291.6   sec/kimg 72.90   maintenance 0.0    cpumem 4.35   gpumem 0.73   reserved 0.92   augment 0.047
# tick 43    kimg 172.0    time 3h 31m 20s   sec/tick 291.0   sec/kimg 72.74   maintenance 0.1    cpumem 4.35   gpumem 0.73   reserved 0.92   augment 0.044
# tick 44    kimg 176.0    time 3h 36m 10s   sec/tick 290.8   sec/kimg 72.71   maintenance 0.0    cpumem 4.35   gpumem 0.73   reserved 0.92   augment 0.044
# tick 45    kimg 180.0    time 3h 41m 01s   sec/tick 290.4   sec/kimg 72.60   maintenance 0.1    cpumem 4.35   gpumem 0.75   reserved 0.92   augment 0.048
# tick 46    kimg 184.0    time 3h 45m 52s   sec/tick 291.5   sec/kimg 72.89   maintenance 0.0    cpumem 4.35   gpumem 0.72   reserved 0.92   augment 0.047
# tick 47    kimg 188.0    time 3h 50m 44s   sec/tick 291.2   sec/kimg 72.81   maintenance 0.1    cpumem 4.35   gpumem 0.75   reserved 0.92   augment 0.047
# tick 48    kimg 192.0    time 3h 55m 36s   sec/tick 291.8   sec/kimg 72.95   maintenance 0.0    cpumem 4.35   gpumem 0.73   reserved 0.92   augment 0.048
# tick 49    kimg 196.0    time 4h 00m 27s   sec/tick 291.6   sec/kimg 72.89   maintenance 0.1    cpumem 4.35   gpumem 0.75   reserved 0.92   augment 0.048
# tick 50    kimg 200.0    time 4h 05m 18s   sec/tick 290.4   sec/kimg 72.60   maintenance 0.0    cpumem 4.35   gpumem 0.74   reserved 0.92   augment 0.050
# tick 51    kimg 204.0    time 4h 10m 23s   sec/tick 290.8   sec/kimg 72.71   maintenance 14.6   cpumem 4.35   gpumem 0.74   reserved 0.92   augment 0.050
# tick 52    kimg 208.0    time 4h 15m 11s   sec/tick 288.1   sec/kimg 72.02   maintenance 0.0    cpumem 4.35   gpumem 0.74   reserved 0.92   augment 0.056
# tick 53    kimg 212.0    time 4h 19m 59s   sec/tick 287.9   sec/kimg 71.98   maintenance 0.1    cpumem 4.35   gpumem 0.74   reserved 0.92   augment 0.059
# tick 54    kimg 216.0    time 4h 24m 46s   sec/tick 286.2   sec/kimg 71.55   maintenance 0.0    cpumem 4.35   gpumem 0.73   reserved 0.92   augment 0.055
# tick 55    kimg 220.0    time 4h 29m 32s   sec/tick 285.9   sec/kimg 71.48   maintenance 0.1    cpumem 4.35   gpumem 0.74   reserved 0.92   augment 0.056
# tick 56    kimg 224.0    time 4h 34m 18s   sec/tick 286.5   sec/kimg 71.62   maintenance 0.0    cpumem 4.35   gpumem 0.73   reserved 0.92   augment 0.057
# tick 57    kimg 228.0    time 4h 39m 05s   sec/tick 286.8   sec/kimg 71.70   maintenance 0.1    cpumem 4.35   gpumem 0.74   reserved 0.92   augment 0.059
# tick 58    kimg 232.0    time 4h 43m 51s   sec/tick 285.7   sec/kimg 71.43   maintenance 0.0    cpumem 4.35   gpumem 0.73   reserved 0.92   augment 0.063
# tick 59    kimg 236.0    time 4h 48m 36s   sec/tick 284.6   sec/kimg 71.16   maintenance 0.1    cpumem 4.35   gpumem 0.74   reserved 0.92   augment 0.065
# tick 60    kimg 240.0    time 4h 53m 20s   sec/tick 284.6   sec/kimg 71.15   maintenance 0.0    cpumem 4.35   gpumem 0.74   reserved 0.92   augment 0.063
# tick 61    kimg 244.0    time 4h 58m 20s   sec/tick 286.1   sec/kimg 71.52   maintenance 13.6   cpumem 4.35   gpumem 0.76   reserved 0.92   augment 0.067
# tick 62    kimg 248.0    time 5h 03m 05s   sec/tick 284.6   sec/kimg 71.16   maintenance 0.0    cpumem 4.35   gpumem 0.73   reserved 0.92   augment 0.069
# tick 63    kimg 252.0    time 5h 07m 49s   sec/tick 284.1   sec/kimg 71.03   maintenance 0.1    cpumem 4.35   gpumem 0.74   reserved 0.92   augment 0.066
# tick 64    kimg 256.0    time 5h 12m 33s   sec/tick 284.2   sec/kimg 71.04   maintenance 0.0    cpumem 4.35   gpumem 0.78   reserved 0.92   augment 0.067
# tick 65    kimg 260.0    time 5h 17m 18s   sec/tick 284.4   sec/kimg 71.10   maintenance 0.1    cpumem 4.35   gpumem 0.75   reserved 0.92   augment 0.064
# tick 66    kimg 264.0    time 5h 22m 02s   sec/tick 284.7   sec/kimg 71.18   maintenance 0.0    cpumem 4.35   gpumem 0.74   reserved 0.92   augment 0.064
# tick 67    kimg 268.0    time 5h 26m 47s   sec/tick 284.1   sec/kimg 71.03   maintenance 0.1    cpumem 4.35   gpumem 0.73   reserved 0.92   augment 0.066
# tick 68    kimg 272.0    time 5h 31m 30s   sec/tick 283.7   sec/kimg 70.94   maintenance 0.0    cpumem 4.35   gpumem 0.73   reserved 0.92   augment 0.066
# tick 69    kimg 276.0    time 5h 36m 14s   sec/tick 284.0   sec/kimg 71.00   maintenance 0.1    cpumem 4.35   gpumem 0.73   reserved 0.92   augment 0.068
# tick 70    kimg 280.0    time 5h 40m 59s   sec/tick 284.1   sec/kimg 71.01   maintenance 0.0    cpumem 4.35   gpumem 0.75   reserved 0.92   augment 0.071
# tick 71    kimg 284.0    time 5h 45m 58s   sec/tick 285.2   sec/kimg 71.31   maintenance 13.9   cpumem 4.35   gpumem 0.75   reserved 0.92   augment 0.076
# tick 72    kimg 288.0    time 5h 50m 43s   sec/tick 285.1   sec/kimg 71.28   maintenance 0.0    cpumem 4.35   gpumem 0.75   reserved 0.92   augment 0.076
# tick 73    kimg 292.0    time 5h 55m 29s   sec/tick 286.3   sec/kimg 71.57   maintenance 0.1    cpumem 4.35   gpumem 0.78   reserved 0.92   augment 0.075
# tick 74    kimg 296.0    time 6h 00m 20s   sec/tick 290.4   sec/kimg 72.61   maintenance 0.0    cpumem 4.35   gpumem 0.75   reserved 0.92   augment 0.073
# tick 75    kimg 300.0    time 6h 05m 10s   sec/tick 290.3   sec/kimg 72.57   maintenance 0.1    cpumem 4.35   gpumem 0.75   reserved 0.92   augment 0.071
# tick 76    kimg 304.0    time 6h 10m 00s   sec/tick 289.4   sec/kimg 72.35   maintenance 0.0    cpumem 4.35   gpumem 0.74   reserved 0.92   augment 0.072
# tick 77    kimg 308.0    time 6h 14m 46s   sec/tick 286.3   sec/kimg 71.58   maintenance 0.1    cpumem 4.35   gpumem 0.76   reserved 0.92   augment 0.074
# tick 78    kimg 312.0    time 6h 19m 32s   sec/tick 285.8   sec/kimg 71.45   maintenance 0.0    cpumem 4.35   gpumem 0.75   reserved 0.92   augment 0.074
# tick 79    kimg 316.0    time 6h 24m 19s   sec/tick 286.7   sec/kimg 71.66   maintenance 0.1    cpumem 4.35   gpumem 0.75   reserved 0.92   augment 0.073
# tick 80    kimg 320.0    time 6h 29m 05s   sec/tick 286.4   sec/kimg 71.60   maintenance 0.0    cpumem 4.35   gpumem 0.74   reserved 0.92   augment 0.074
# tick 81    kimg 324.0    time 6h 34m 07s   sec/tick 287.1   sec/kimg 71.79   maintenance 14.6   cpumem 4.35   gpumem 0.76   reserved 0.92   augment 0.074
# tick 82    kimg 328.0    time 6h 38m 52s   sec/tick 284.9   sec/kimg 71.23   maintenance 0.0    cpumem 4.35   gpumem 0.75   reserved 0.92   augment 0.074
# tick 83    kimg 332.0    time 6h 43m 37s   sec/tick 285.4   sec/kimg 71.35   maintenance 0.1    cpumem 4.35   gpumem 0.77   reserved 0.92   augment 0.077
# tick 84    kimg 336.0    time 6h 48m 23s   sec/tick 285.5   sec/kimg 71.37   maintenance 0.0    cpumem 4.35   gpumem 0.74   reserved 0.92   augment 0.076
# tick 85    kimg 340.0    time 6h 53m 07s   sec/tick 284.3   sec/kimg 71.08   maintenance 0.1    cpumem 4.35   gpumem 0.77   reserved 0.92   augment 0.076
# tick 86    kimg 344.0    time 6h 57m 57s   sec/tick 289.9   sec/kimg 72.48   maintenance 0.0    cpumem 4.35   gpumem 0.75   reserved 0.92   augment 0.075
# tick 87    kimg 348.0    time 7h 02m 46s   sec/tick 288.8   sec/kimg 72.20   maintenance 0.1    cpumem 4.35   gpumem 0.75   reserved 0.92   augment 0.080
# tick 88    kimg 352.0    time 7h 07m 33s   sec/tick 286.6   sec/kimg 71.65   maintenance 0.0    cpumem 4.35   gpumem 0.75   reserved 0.92   augment 0.084
# tick 89    kimg 356.0    time 7h 12m 19s   sec/tick 286.2   sec/kimg 71.54   maintenance 0.1    cpumem 4.35   gpumem 0.75   reserved 0.92   augment 0.083
# tick 90    kimg 360.0    time 7h 17m 04s   sec/tick 285.1   sec/kimg 71.27   maintenance 0.0    cpumem 4.35   gpumem 0.74   reserved 0.92   augment 0.084
# tick 91    kimg 364.0    time 7h 22m 05s   sec/tick 286.8   sec/kimg 71.71   maintenance 14.0   cpumem 4.36   gpumem 0.74   reserved 0.92   augment 0.085
# tick 92    kimg 368.0    time 7h 26m 49s   sec/tick 283.7   sec/kimg 70.92   maintenance 0.0    cpumem 4.36   gpumem 0.76   reserved 0.92   augment 0.086
# tick 93    kimg 372.0    time 7h 31m 33s   sec/tick 284.3   sec/kimg 71.08   maintenance 0.1    cpumem 4.36   gpumem 0.73   reserved 0.92   augment 0.087
# tick 94    kimg 376.0    time 7h 36m 17s   sec/tick 283.5   sec/kimg 70.87   maintenance 0.0    cpumem 4.36   gpumem 0.75   reserved 0.92   augment 0.086
# tick 95    kimg 380.0    time 7h 41m 00s   sec/tick 282.7   sec/kimg 70.67   maintenance 0.1    cpumem 4.36   gpumem 0.76   reserved 0.92   augment 0.089
# tick 96    kimg 384.0    time 7h 45m 43s   sec/tick 283.0   sec/kimg 70.75   maintenance 0.0    cpumem 4.36   gpumem 0.75   reserved 0.92   augment 0.092
# tick 97    kimg 388.0    time 7h 50m 26s   sec/tick 283.3   sec/kimg 70.84   maintenance 0.1    cpumem 4.36   gpumem 0.75   reserved 0.92   augment 0.093
# tick 98    kimg 392.0    time 7h 55m 08s   sec/tick 282.1   sec/kimg 70.53   maintenance 0.0    cpumem 4.36   gpumem 0.73   reserved 0.92   augment 0.092
# tick 99    kimg 396.0    time 7h 59m 50s   sec/tick 282.1   sec/kimg 70.53   maintenance 0.1    cpumem 4.36   gpumem 0.74   reserved 0.92   augment 0.093
# tick 100   kimg 400.0    time 8h 04m 33s   sec/tick 282.6   sec/kimg 70.66   maintenance 0.0    cpumem 4.36   gpumem 0.74   reserved 0.92   augment 0.094
# tick 101   kimg 404.0    time 8h 09m 32s   sec/tick 284.3   sec/kimg 71.08   maintenance 14.2   cpumem 4.36   gpumem 0.77   reserved 0.92   augment 0.092
# tick 102   kimg 408.0    time 8h 14m 14s   sec/tick 282.1   sec/kimg 70.53   maintenance 0.0    cpumem 4.36   gpumem 0.74   reserved 0.93   augment 0.094
# tick 103   kimg 412.0    time 8h 18m 56s   sec/tick 281.9   sec/kimg 70.49   maintenance 0.1    cpumem 4.36   gpumem 0.75   reserved 0.93   augment 0.096
# tick 104   kimg 416.0    time 8h 23m 38s   sec/tick 281.9   sec/kimg 70.48   maintenance 0.0    cpumem 4.36   gpumem 0.75   reserved 0.93   augment 0.093
# tick 105   kimg 420.0    time 8h 28m 20s   sec/tick 282.2   sec/kimg 70.56   maintenance 0.1    cpumem 4.36   gpumem 0.77   reserved 0.93   augment 0.096
# tick 106   kimg 424.0    time 8h 33m 02s   sec/tick 281.4   sec/kimg 70.36   maintenance 0.0    cpumem 4.36   gpumem 0.74   reserved 0.93   augment 0.093
# tick 107   kimg 428.0    time 8h 37m 44s   sec/tick 281.9   sec/kimg 70.49   maintenance 0.1    cpumem 4.36   gpumem 0.75   reserved 0.93   augment 0.097
# tick 108   kimg 432.0    time 8h 42m 25s   sec/tick 281.7   sec/kimg 70.42   maintenance 0.0    cpumem 4.36   gpumem 0.75   reserved 0.93   augment 0.097
# tick 109   kimg 436.0    time 8h 47m 07s   sec/tick 281.4   sec/kimg 70.35   maintenance 0.1    cpumem 4.36   gpumem 0.74   reserved 0.93   augment 0.101
# tick 110   kimg 440.0    time 8h 51m 48s   sec/tick 281.5   sec/kimg 70.38   maintenance 0.0    cpumem 4.36   gpumem 0.78   reserved 0.93   augment 0.098
# tick 111   kimg 444.0    time 8h 56m 46s   sec/tick 283.9   sec/kimg 70.98   maintenance 13.6   cpumem 4.36   gpumem 0.74   reserved 0.93   augment 0.098
# tick 112   kimg 448.0    time 9h 01m 28s   sec/tick 282.3   sec/kimg 70.58   maintenance 0.0    cpumem 4.36   gpumem 0.77   reserved 0.93   augment 0.102
# tick 113   kimg 452.0    time 9h 06m 11s   sec/tick 282.3   sec/kimg 70.57   maintenance 0.1    cpumem 4.36   gpumem 0.76   reserved 0.93   augment 0.104
# tick 114   kimg 456.0    time 9h 10m 53s   sec/tick 282.1   sec/kimg 70.53   maintenance 0.0    cpumem 4.36   gpumem 0.76   reserved 0.93   augment 0.102
# tick 115   kimg 460.0    time 9h 15m 35s   sec/tick 282.4   sec/kimg 70.61   maintenance 0.1    cpumem 4.36   gpumem 0.78   reserved 0.93   augment 0.105

# %%
#FID SCORE
# !python /kaggle/working/stylegan3/calc_metrics.py \
  --gpus=1 \
  --data=/kaggle/input/anthmango512x512 \
  --network=/kaggle/input/trained/other/default/1/network-snapshot-000240.pkl \
  --metrics=fid50k_full

# %%
# !python gen_images.py \
  --outdir=ANTHgenerated-images \
  --trunc=0.5 \
  --seeds=0-99 \
   --network=/kaggle/input/trained/other/default/1/network-snapshot-000240.pkl

# %%
#ziping generated image
# !zip -r ANTHgenerated-images1.zip ANTHgenerated-images

# %%
#GENERATING IMAGES
# !python gen_images.py \
  --outdir=generated-images \
  --trunc=0.7 \
  --seeds=0-99 \
  --network=/kaggle/working/stylegan3/training-runs/00002-stylegan3-t-MangoLeaf-gpus2-batch4-gamma8.2/network-snapshot-000300.pkl

# %%
#ziping generated image
# !zip -r generated-images4.zip generated-images

# %%
#RAN SUCCESSFULLY
# !python train.py \
  --outdir=training-runs \
  --data=MangoLeaf.zip \
  --gpus=1 \
  --batch=2 \
  --gamma=8.2 \
  --snap=1 \
  --cfg=stylegan3-t \
  --mirror=0 \
  --aug=noaug \
  --kimg=2 \
  --cbase=16384 --cmax=64 \
  --mbstd-group=1

# %%
#FOR 1024X1024 IMAGES
# !python train.py \
  --outdir=training-runs \
  --data=MangoLeaf1024.zip \
  --gpus=2 \
  --batch=2 \
  --gamma=8.2 \
  --snap=10 \
  --cfg=stylegan3-t \
  --mirror=0 \
  --aug=ada \
  --kimg=200 \
  --cbase=8192 --cmax=64 \
  --mbstd-group=1 \
  --metrics=none
