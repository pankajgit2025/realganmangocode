# %%
import tensorflow as tf
from tensorflow.keras.applications import EfficientNetB1, EfficientNetB2, EfficientNetB3, EfficientNetB4, EfficientNetB5, EfficientNetB6, EfficientNetB7
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.efficientnet import preprocess_input
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
import os

# Define EfficientNet models and corresponding input sizes
efficientnet_versions = {
    'EfficientNetB5': (EfficientNetB5, 456),
    'EfficientNetB6': (EfficientNetB6, 528),
    'EfficientNetB7': (EfficientNetB7, 600)
}

# Dataset paths
base_path = '/kaggle/input/ganmango512x512/GANSplit512x512/'
train_path = os.path.join(base_path, 'train')
val_path = os.path.join(base_path, 'val')
test_path = os.path.join(base_path, 'test')

# Store results
results = []

# Training and Evaluation Loop
for model_name, (model_class, img_size) in efficientnet_versions.items():
    print(f"\nTraining {model_name} with input size {img_size}x{img_size}")

    datagen = ImageDataGenerator(preprocessing_function=preprocess_input)

    train_gen = datagen.flow_from_directory(
        train_path,
        target_size=(img_size, img_size),
        batch_size=32,
        class_mode='categorical'
    )
    val_gen = datagen.flow_from_directory(
        val_path,
        target_size=(img_size, img_size),
        batch_size=32,
        class_mode='categorical'
    )
    test_gen = datagen.flow_from_directory(
        test_path,
        target_size=(img_size, img_size),
        batch_size=32,
        class_mode='categorical',
        shuffle=False
    )

    base_model = model_class(weights='imagenet', include_top=False, input_shape=(img_size, img_size, 3))
    base_model.trainable = False

    x = GlobalAveragePooling2D()(base_model.output)
    x = Dropout(0.5)(x)
    output = Dense(train_gen.num_classes, activation='softmax')(x)

    model = Model(inputs=base_model.input, outputs=output)
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

    history = model.fit(
        train_gen,
        validation_data=val_gen,
        epochs=10,
        verbose=1
    )

    # Plot Train vs Validation Accuracy and Loss
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Train Accuracy')
    plt.plot(history.history['val_accuracy'], label='Val Accuracy')
    plt.title(f'{model_name} Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Val Loss')
    plt.title(f'{model_name} Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    plt.tight_layout()
    plt.show()

    # Evaluate on test set
    test_loss, test_acc = model.evaluate(test_gen)
    print(f"Test Accuracy for {model_name}: {test_acc:.4f}")

    # Predict
    y_pred = model.predict(test_gen)
    y_pred_classes = np.argmax(y_pred, axis=1)
    y_true = test_gen.classes
    class_labels = list(test_gen.class_indices.keys())

    # Classification Report
    report = classification_report(y_true, y_pred_classes, target_names=class_labels)
    print(f"\nClassification Report for {model_name}:\n{report}")

    # Confusion Matrix
    cm = confusion_matrix(y_true, y_pred_classes)
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_labels, yticklabels=class_labels)
    plt.title(f'{model_name} - Confusion Matrix')
    plt.ylabel('True Label')
    plt.xlabel('Predicted Label')
    plt.show()

    # Save results
    results.append({
        'Model': model_name,
        'Input Size': img_size,
        'Test Accuracy': test_acc
    })

# Display all model accuracies
df_results = pd.DataFrame(results)
print("\nSummary of Results:")
print(df_results)

# Optionally save results
# df_results.to_csv("efficientnet_results.csv", index=False)
# Out:
# 2025-06-05 17:10:50.086976: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1749143450.330662      35 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1749143450.407414      35 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Training EfficientNetB5 with input size 456x456
# Found 42000 images belonging to 6 classes.
# Found 9000 images belonging to 6 classes.
# Found 9000 images belonging to 6 classes.
# I0000 00:00:1749143483.793798      35 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb5_notop.h5
# 115263384/115263384 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/10
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1749143531.881893     112 service.cc:148] XLA service 0x7a7c7c0023f0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1749143531.883136     112 service.cc:156]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1749143536.419079     112 cuda_dnn.cc:529] Loaded cuDNN version 90300
# I0000 00:00:1749143563.181315     112 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 1094s 780ms/step - accuracy: 0.8972 - loss: 0.3598 - val_accuracy: 0.9939 - val_loss: 0.0401
# Epoch 2/10
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 873s 665ms/step - accuracy: 0.9852 - loss: 0.0622 - val_accuracy: 0.9957 - val_loss: 0.0224
# Epoch 3/10
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 789s 601ms/step - accuracy: 0.9894 - loss: 0.0396 - val_accuracy: 0.9970 - val_loss: 0.0147
# Epoch 4/10
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 744s 566ms/step - accuracy: 0.9897 - loss: 0.0351 - val_accuracy: 0.9971 - val_loss: 0.0126
# Epoch 5/10
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 702s 535ms/step - accuracy: 0.9908 - loss: 0.0301 - val_accuracy: 0.9978 - val_loss: 0.0103
# Epoch 6/10
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 704s 536ms/step - accuracy: 0.9902 - loss: 0.0295 - val_accuracy: 0.9972 - val_loss: 0.0099
# Epoch 7/10
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 721s 549ms/step - accuracy: 0.9909 - loss: 0.0277 - val_accuracy: 0.9978 - val_loss: 0.0075
# Epoch 8/10
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 718s 547ms/step - accuracy: 0.9914 - loss: 0.0260 - val_accuracy: 0.9979 - val_loss: 0.0077
# Epoch 9/10
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 699s 532ms/step - accuracy: 0.9922 - loss: 0.0265 - val_accuracy: 0.9986 - val_loss: 0.0065
# Epoch 10/10
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 683s 520ms/step - accuracy: 0.9925 - loss: 0.0251 - val_accuracy: 0.9984 - val_loss: 0.0064
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 222s 788ms/step - accuracy: 0.9981 - loss: 0.0064
# Test Accuracy for EfficientNetB5: 0.9974
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 205s 674ms/step
#
# Classification Report for EfficientNetB5:
#                     precision    recall  f1-score   support
#
#        ANTHRECNOSE       1.00      1.00      1.00      1500
#            DIEBACK       1.00      1.00      1.00      1500
#   GALLMILDGEDAMAGE       1.00      1.00      1.00      1500
#            HEALTHY       1.00      1.00      1.00      1500
# INSECTDAMAGEWEBBER       1.00      0.99      1.00      1500
#         LEAFBLIGHT       1.00      1.00      1.00      1500
#
#           accuracy                           1.00      9000
#          macro avg       1.00      1.00      1.00      9000
#       weighted avg       1.00      1.00      1.00      9000
# Training EfficientNetB6 with input size 528x528
# Found 42000 images belonging to 6 classes.
# Found 9000 images belonging to 6 classes.
# Found 9000 images belonging to 6 classes.
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb6_notop.h5
# 165234480/165234480 ━━━━━━━━━━━━━━━━━━━━ 5s 0us/step
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/10
# 2025-06-05 19:28:54.326325: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng3{k11=2} for conv (f32[32,40,132,132]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,240,132,132]{3,2,1,0}, f32[40,240,1,1]{3,2,1,0}), window={size=1x1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-06-05 19:28:54.357938: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.031805788s
# Trying algorithm eng3{k11=2} for conv (f32[32,40,132,132]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,240,132,132]{3,2,1,0}, f32[40,240,1,1]{3,2,1,0}), window={size=1x1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 1198s 847ms/step - accuracy: 0.9038 - loss: 0.3663 - val_accuracy: 0.9947 - val_loss: 0.0376
# Epoch 2/10
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 1017s 774ms/step - accuracy: 0.9889 - loss: 0.0526 - val_accuracy: 0.9971 - val_loss: 0.0186
# Epoch 3/10
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 908s 691ms/step - accuracy: 0.9903 - loss: 0.0373 - val_accuracy: 0.9973 - val_loss: 0.0124
# Epoch 4/10
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 895s 681ms/step - accuracy: 0.9918 - loss: 0.0309 - val_accuracy: 0.9988 - val_loss: 0.0085
# Epoch 5/10
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 901s 686ms/step - accuracy: 0.9934 - loss: 0.0238 - val_accuracy: 0.9982 - val_loss: 0.0078
# Epoch 6/10
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 950s 723ms/step - accuracy: 0.9937 - loss: 0.0221 - val_accuracy: 0.9984 - val_loss: 0.0072
# Epoch 7/10
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 914s 696ms/step - accuracy: 0.9938 - loss: 0.0212 - val_accuracy: 0.9993 - val_loss: 0.0048
# Epoch 8/10
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 918s 699ms/step - accuracy: 0.9932 - loss: 0.0206 - val_accuracy: 0.9986 - val_loss: 0.0046
# Epoch 9/10
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 930s 708ms/step - accuracy: 0.9943 - loss: 0.0186 - val_accuracy: 0.9987 - val_loss: 0.0052
# Epoch 10/10
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 1135s 864ms/step - accuracy: 0.9943 - loss: 0.0188 - val_accuracy: 0.9990 - val_loss: 0.0047
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 366s 1s/step - accuracy: 0.9983 - loss: 0.0058
# Test Accuracy for EfficientNetB6: 0.9981
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 236s 763ms/step
#
# Classification Report for EfficientNetB6:
#                     precision    recall  f1-score   support
#
#        ANTHRECNOSE       1.00      1.00      1.00      1500
#            DIEBACK       1.00      1.00      1.00      1500
#   GALLMILDGEDAMAGE       1.00      1.00      1.00      1500
#            HEALTHY       1.00      1.00      1.00      1500
# INSECTDAMAGEWEBBER       1.00      0.99      1.00      1500
#         LEAFBLIGHT       1.00      1.00      1.00      1500
#
#           accuracy                           1.00      9000
#          macro avg       1.00      1.00      1.00      9000
#       weighted avg       1.00      1.00      1.00      9000
# Training EfficientNetB7 with input size 600x600
# Found 42000 images belonging to 6 classes.
# Found 9000 images belonging to 6 classes.
# Found 9000 images belonging to 6 classes.
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb7_notop.h5
# 258076736/258076736 ━━━━━━━━━━━━━━━━━━━━ 7s 0us/step
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/10
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 1735s 1s/step - accuracy: 0.9159 - loss: 0.3200 - val_accuracy: 0.9959 - val_loss: 0.0282
# Epoch 2/10
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 1540s 1s/step - accuracy: 0.9907 - loss: 0.0403 - val_accuracy: 0.9981 - val_loss: 0.0141
# Epoch 3/10
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 1495s 1s/step - accuracy: 0.9937 - loss: 0.0257 - val_accuracy: 0.9982 - val_loss: 0.0103
# Epoch 4/10
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 1498s 1s/step - accuracy: 0.9953 - loss: 0.0195 - val_accuracy: 0.9983 - val_loss: 0.0085
# Epoch 5/10
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 1495s 1s/step - accuracy: 0.9950 - loss: 0.0188 - val_accuracy: 0.9987 - val_loss: 0.0061
# Epoch 6/10
#  131/1313 ━━━━━━━━━━━━━━━━━━━━ 18:27 937ms/step - accuracy: 0.9971 - loss: 0.0129
