# %%
import tensorflow as tf
from tensorflow.keras.applications import EfficientNetB1, EfficientNetB2, EfficientNetB3, EfficientNetB4, EfficientNetB5, EfficientNetB6, EfficientNetB7
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.efficientnet import preprocess_input
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
import os

# Define EfficientNet models and corresponding input sizes
efficientnet_versions = {
    'EfficientNetB4': (EfficientNetB4, 380),
    'EfficientNetB5': (EfficientNetB5, 456),
    'EfficientNetB6': (EfficientNetB6, 528),
    'EfficientNetB7': (EfficientNetB7, 600)
}

# Dataset paths
base_path = '/kaggle/input/ganmango512x512/GANSplit512x512/'
train_path = os.path.join(base_path, 'train')
val_path = os.path.join(base_path, 'val')
test_path = os.path.join(base_path, 'test')

# Store results
results = []

# Training and Evaluation Loop
for model_name, (model_class, img_size) in efficientnet_versions.items():
    print(f"\nTraining {model_name} with input size {img_size}x{img_size}")

    datagen = ImageDataGenerator(preprocessing_function=preprocess_input)

    train_gen = datagen.flow_from_directory(
        train_path,
        target_size=(img_size, img_size),
        batch_size=32,
        class_mode='categorical'
    )
    val_gen = datagen.flow_from_directory(
        val_path,
        target_size=(img_size, img_size),
        batch_size=32,
        class_mode='categorical'
    )
    test_gen = datagen.flow_from_directory(
        test_path,
        target_size=(img_size, img_size),
        batch_size=32,
        class_mode='categorical',
        shuffle=False
    )

    base_model = model_class(weights='imagenet', include_top=False, input_shape=(img_size, img_size, 3))
    base_model.trainable = False

    x = GlobalAveragePooling2D()(base_model.output)
    x = Dropout(0.5)(x)
    output = Dense(train_gen.num_classes, activation='softmax')(x)

    model = Model(inputs=base_model.input, outputs=output)
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

    history = model.fit(
        train_gen,
        validation_data=val_gen,
        epochs=10,
        verbose=1
    )

    # Plot Train vs Validation Accuracy and Loss
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Train Accuracy')
    plt.plot(history.history['val_accuracy'], label='Val Accuracy')
    plt.title(f'{model_name} Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Val Loss')
    plt.title(f'{model_name} Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    plt.tight_layout()
    plt.show()

    # Evaluate on test set
    test_loss, test_acc = model.evaluate(test_gen)
    print(f"Test Accuracy for {model_name}: {test_acc:.4f}")

    # Predict
    y_pred = model.predict(test_gen)
    y_pred_classes = np.argmax(y_pred, axis=1)
    y_true = test_gen.classes
    class_labels = list(test_gen.class_indices.keys())

    # Classification Report
    report = classification_report(y_true, y_pred_classes, target_names=class_labels)
    print(f"\nClassification Report for {model_name}:\n{report}")

    # Confusion Matrix
    cm = confusion_matrix(y_true, y_pred_classes)
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_labels, yticklabels=class_labels)
    plt.title(f'{model_name} - Confusion Matrix')
    plt.ylabel('True Label')
    plt.xlabel('Predicted Label')
    plt.show()

    # Save results
    results.append({
        'Model': model_name,
        'Input Size': img_size,
        'Test Accuracy': test_acc
    })

# Display all model accuracies
df_results = pd.DataFrame(results)
print("\nSummary of Results:")
print(df_results)

# Optionally save results
# df_results.to_csv("efficientnet_results.csv", index=False)
# Out:
# 2025-06-05 13:50:58.380568: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1749131458.850768      35 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1749131458.967169      35 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Training EfficientNetB4 with input size 380x380
# Found 42000 images belonging to 6 classes.
# Found 9000 images belonging to 6 classes.
# Found 9000 images belonging to 6 classes.
# I0000 00:00:1749131509.092585      35 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13942 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1749131509.093296      35 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13942 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb4_notop.h5
# 71686520/71686520 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/10
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1749131545.214946     115 service.cc:148] XLA service 0x7993d4002290 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1749131545.216443     115 service.cc:156]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1749131545.216469     115 service.cc:156]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1749131548.915834     115 cuda_dnn.cc:529] Loaded cuDNN version 90300
# E0000 00:00:1749131554.790078     115 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1749131555.009892     115 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# I0000 00:00:1749131571.617224     115 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
#    6/1313 ━━━━━━━━━━━━━━━━━━━━ 11:03 508ms/step - accuracy: 0.2607 - loss: 1.7606
# E0000 00:00:1749131581.496793     115 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1749131581.678093     115 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 0s 645ms/step - accuracy: 0.8828 - loss: 0.3952
# E0000 00:00:1749132612.402844     117 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1749132612.559709     117 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 1103s 797ms/step - accuracy: 0.8828 - loss: 0.3950 - val_accuracy: 0.9872 - val_loss: 0.0604
# Epoch 2/10
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 813s 619ms/step - accuracy: 0.9747 - loss: 0.0905 - val_accuracy: 0.9920 - val_loss: 0.0362
# Epoch 3/10
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 693s 528ms/step - accuracy: 0.9766 - loss: 0.0711 - val_accuracy: 0.9936 - val_loss: 0.0272
# Epoch 4/10
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 661s 504ms/step - accuracy: 0.9794 - loss: 0.0637 - val_accuracy: 0.9934 - val_loss: 0.0252
# Epoch 5/10
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 655s 499ms/step - accuracy: 0.9823 - loss: 0.0553 - val_accuracy: 0.9956 - val_loss: 0.0189
# Epoch 6/10
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 679s 517ms/step - accuracy: 0.9814 - loss: 0.0546 - val_accuracy: 0.9958 - val_loss: 0.0176
# Epoch 7/10
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 673s 513ms/step - accuracy: 0.9833 - loss: 0.0502 - val_accuracy: 0.9963 - val_loss: 0.0150
# Epoch 8/10
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 679s 517ms/step - accuracy: 0.9843 - loss: 0.0500 - val_accuracy: 0.9967 - val_loss: 0.0148
# Epoch 9/10
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 676s 514ms/step - accuracy: 0.9821 - loss: 0.0512 - val_accuracy: 0.9971 - val_loss: 0.0128
# Epoch 10/10
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 690s 525ms/step - accuracy: 0.9823 - loss: 0.0480 - val_accuracy: 0.9966 - val_loss: 0.0127
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 200s 709ms/step - accuracy: 0.9963 - loss: 0.0123
# Test Accuracy for EfficientNetB4: 0.9956
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 192s 632ms/step
#
# Classification Report for EfficientNetB4:
#                     precision    recall  f1-score   support
#
#        ANTHRECNOSE       1.00      0.99      1.00      1500
#            DIEBACK       1.00      1.00      1.00      1500
#   GALLMILDGEDAMAGE       0.99      1.00      0.99      1500
#            HEALTHY       0.99      1.00      1.00      1500
# INSECTDAMAGEWEBBER       0.99      0.99      0.99      1500
#         LEAFBLIGHT       0.99      1.00      0.99      1500
#
#           accuracy                           1.00      9000
#          macro avg       1.00      1.00      1.00      9000
#       weighted avg       1.00      1.00      1.00      9000
# Training EfficientNetB5 with input size 456x456
# Found 42000 images belonging to 6 classes.
# Found 9000 images belonging to 6 classes.
# Found 9000 images belonging to 6 classes.
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb5_notop.h5
# 115263384/115263384 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/10
# E0000 00:00:1749139318.064001     115 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1749139318.325911     115 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
#  500/1313 ━━━━━━━━━━━━━━━━━━━━ 7:47 575ms/step - accuracy: 0.8331 - loss: 0.5775
# E0000 00:00:1749139638.345438     117 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1749139638.549675     117 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 0s 654ms/step - accuracy: 0.9027 - loss: 0.3602
# E0000 00:00:1749140452.425549     116 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1749140452.594139     116 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 1189s 851ms/step - accuracy: 0.9028 - loss: 0.3600 - val_accuracy: 0.9927 - val_loss: 0.0400
# Epoch 2/10
#   92/1313 ━━━━━━━━━━━━━━━━━━━━ 11:53 584ms/step - accuracy: 0.9791 - loss: 0.0799
