# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input/mangoleafdiseasedataset224x224/MangoLeafDiseaseDataset224x224'):
    for filename in filenames:
        pass
        #print(os.path.join(dirname, filename))
print("hello")

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# hello

# %%
import tensorflow as tf
from tensorflow.keras.applications import VGG19
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

# Load the VGG19 model without the top (fully connected) layers
base_model = VGG19(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Freeze all convolutional layers
for layer in base_model.layers:
    layer.trainable = False

# Flatten the output of the convolutional base
x = Flatten()(base_model.output)
x = Dense(256, activation='relu')(x)
x = Dropout(0.5)(x)  # Add dropout to reduce overfitting
x = Dense(6, activation='softmax')(x)  # 6-class classification

# Create the new model
model = Model(inputs=base_model.input, outputs=x)

# Compile the model
model.compile(
    optimizer='adam', 
    loss='categorical_crossentropy',  # Multi-class classification
    metrics=['accuracy']
)

# Print the model summary
model.summary()

# Define ImageDataGenerator without augmentation
train_datagen = ImageDataGenerator(rescale=1./255)  # Only rescale for training
val_datagen = ImageDataGenerator(rescale=1./255)    # Only rescale for validation
test_datagen = ImageDataGenerator(rescale=1./255)   # Only rescale for test

# Load Training Data
train_generator = train_datagen.flow_from_directory(
    '/kaggle/input/mangoleafdiseasedataset224x224/MangoLeafDiseaseDataset224x224/train',   # Path to train folder
    target_size=(224, 224), 
    batch_size=32,
    class_mode='categorical'  # Multi-class classification (8 classes)
)

# Load Validation Data
val_generator = val_datagen.flow_from_directory(
    '/kaggle/input/mangoleafdiseasedataset224x224/MangoLeafDiseaseDataset224x224/val',   # Path to validation folder
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical'
)

# Load Test Data (For final evaluation)
test_generator = test_datagen.flow_from_directory(
    '/kaggle/input/mangoleafdiseasedataset224x224/MangoLeafDiseaseDataset224x224/test',   # Path to test folder
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    shuffle=False   # No shuffling for test set
)

# Train the Model
history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=30  # You can adjust the number of epochs as needed
)

# Plot Training & Validation Accuracy
plt.figure(figsize=(8, 5))
plt.plot(history.history['accuracy'], label='Train Accuracy', marker='o')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy', marker='s')

plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training vs. Validation Accuracy Without Augmentation using VGG19')
plt.legend()
plt.grid(True)
plt.show()

# Evaluate on test data
test_loss, test_acc = model.evaluate(test_generator)
print(f"\nTest Accuracy: {test_acc:.4f}")

# Confusion matrix and classification report
y_true = test_generator.classes
y_pred_probs = model.predict(test_generator)
y_pred = np.argmax(y_pred_probs, axis=1)

# Classification report
print("\nClassification Report VGG19 Without Aug:")
print(classification_report(y_true, y_pred, target_names=test_generator.class_indices.keys()))

# Confusion matrix
cm = confusion_matrix(y_true, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=test_generator.class_indices.keys())
disp.plot(cmap='Blues', xticks_rotation=45)
plt.title("Confusion Matrix - VGG19 Without Aug")
plt.show()
# Out:
# 2025-05-03 17:56:25.964558: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1746294986.198461      31 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1746294986.265860      31 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# I0000 00:00:1746294999.892373      31 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13942 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1746294999.893166      31 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13942 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 224, 224, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv1 (Conv2D)                │ (None, 224, 224, 64)        │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv2 (Conv2D)                │ (None, 224, 224, 64)        │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_pool (MaxPooling2D)           │ (None, 112, 112, 64)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_conv1 (Conv2D)                │ (None, 112, 112, 128)       │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_conv2 (Conv2D)                │ (None, 112, 112, 128)       │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_pool (MaxPooling2D)           │ (None, 56, 56, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv1 (Conv2D)                │ (None, 56, 56, 256)         │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv2 (Conv2D)                │ (None, 56, 56, 256)         │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv3 (Conv2D)                │ (None, 56, 56, 256)         │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv4 (Conv2D)                │ (None, 56, 56, 256)         │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_pool (MaxPooling2D)           │ (None, 28, 28, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv1 (Conv2D)                │ (None, 28, 28, 512)         │       1,180,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv2 (Conv2D)                │ (None, 28, 28, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv3 (Conv2D)                │ (None, 28, 28, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv4 (Conv2D)                │ (None, 28, 28, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_pool (MaxPooling2D)           │ (None, 14, 14, 512)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv1 (Conv2D)                │ (None, 14, 14, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv2 (Conv2D)                │ (None, 14, 14, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv3 (Conv2D)                │ (None, 14, 14, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv4 (Conv2D)                │ (None, 14, 14, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_pool (MaxPooling2D)           │ (None, 7, 7, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 25088)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 256)                 │       6,422,784 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 6)                   │           1,542 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 26,448,710 (100.89 MB)
#  Trainable params: 6,424,326 (24.51 MB)
#  Non-trainable params: 20,024,384 (76.39 MB)
# Found 4646 images belonging to 6 classes.
# Found 993 images belonging to 6 classes.
# Found 1001 images belonging to 6 classes.
# Epoch 1/30
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1746295013.632202      92 service.cc:148] XLA service 0x78273800e750 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1746295013.633207      92 service.cc:156]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1746295013.633229      92 service.cc:156]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1746295014.028516      92 cuda_dnn.cc:529] Loaded cuDNN version 90300
#   1/146 ━━━━━━━━━━━━━━━━━━━━ 38:31 16s/step - accuracy: 0.2188 - loss: 2.0691
# I0000 00:00:1746295025.515052      92 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 57s 284ms/step - accuracy: 0.3868 - loss: 2.0183 - val_accuracy: 0.7251 - val_loss: 0.8629
# Epoch 2/30
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 37s 252ms/step - accuracy: 0.6118 - loss: 1.0135 - val_accuracy: 0.7825 - val_loss: 0.6635
# Epoch 3/30
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 39s 264ms/step - accuracy: 0.6829 - loss: 0.8243 - val_accuracy: 0.7885 - val_loss: 0.6911
# Epoch 4/30
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 38s 257ms/step - accuracy: 0.6991 - loss: 0.7836 - val_accuracy: 0.8429 - val_loss: 0.4832
# Epoch 5/30
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 39s 262ms/step - accuracy: 0.7468 - loss: 0.6515 - val_accuracy: 0.8479 - val_loss: 0.4439
# Epoch 6/30
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 38s 260ms/step - accuracy: 0.7436 - loss: 0.6416 - val_accuracy: 0.8419 - val_loss: 0.4407
# Epoch 7/30
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 38s 259ms/step - accuracy: 0.7616 - loss: 0.5859 - val_accuracy: 0.8671 - val_loss: 0.4118
# Epoch 8/30
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 38s 259ms/step - accuracy: 0.7929 - loss: 0.5477 - val_accuracy: 0.8429 - val_loss: 0.4326
# Epoch 9/30
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 38s 260ms/step - accuracy: 0.7790 - loss: 0.5421 - val_accuracy: 0.8610 - val_loss: 0.3825
# Epoch 10/30
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 39s 262ms/step - accuracy: 0.8115 - loss: 0.4740 - val_accuracy: 0.8822 - val_loss: 0.3621
# Epoch 11/30
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 38s 260ms/step - accuracy: 0.8010 - loss: 0.4869 - val_accuracy: 0.8731 - val_loss: 0.4063
# Epoch 12/30
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 38s 260ms/step - accuracy: 0.8092 - loss: 0.4617 - val_accuracy: 0.8912 - val_loss: 0.3668
# Epoch 13/30
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 38s 261ms/step - accuracy: 0.8176 - loss: 0.4388 - val_accuracy: 0.8983 - val_loss: 0.3175
# Epoch 14/30
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 39s 261ms/step - accuracy: 0.8268 - loss: 0.4385 - val_accuracy: 0.8912 - val_loss: 0.3429
# Epoch 15/30
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 38s 261ms/step - accuracy: 0.8244 - loss: 0.4093 - val_accuracy: 0.8943 - val_loss: 0.3188
# Epoch 16/30
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 38s 260ms/step - accuracy: 0.8121 - loss: 0.4409 - val_accuracy: 0.8761 - val_loss: 0.3731
# Epoch 17/30
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 39s 261ms/step - accuracy: 0.8250 - loss: 0.4130 - val_accuracy: 0.9053 - val_loss: 0.3094
# Epoch 18/30
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 39s 262ms/step - accuracy: 0.8311 - loss: 0.3981 - val_accuracy: 0.8993 - val_loss: 0.3561
# Epoch 19/30
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 39s 261ms/step - accuracy: 0.8195 - loss: 0.4265 - val_accuracy: 0.9114 - val_loss: 0.3150
# Epoch 20/30
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 39s 261ms/step - accuracy: 0.8224 - loss: 0.4107 - val_accuracy: 0.8993 - val_loss: 0.3373
# Epoch 21/30
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 38s 260ms/step - accuracy: 0.8223 - loss: 0.4006 - val_accuracy: 0.9134 - val_loss: 0.3219
# Epoch 22/30
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 38s 260ms/step - accuracy: 0.8341 - loss: 0.3830 - val_accuracy: 0.8933 - val_loss: 0.3299
# Epoch 23/30
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 39s 261ms/step - accuracy: 0.8322 - loss: 0.3881 - val_accuracy: 0.9074 - val_loss: 0.2907
# Epoch 24/30
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 39s 261ms/step - accuracy: 0.8462 - loss: 0.3739 - val_accuracy: 0.9084 - val_loss: 0.2959
# Epoch 25/30
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 38s 261ms/step - accuracy: 0.8613 - loss: 0.3319 - val_accuracy: 0.9114 - val_loss: 0.3137
# Epoch 26/30
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 39s 261ms/step - accuracy: 0.8493 - loss: 0.3518 - val_accuracy: 0.9043 - val_loss: 0.3566
# Epoch 27/30
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 38s 260ms/step - accuracy: 0.8499 - loss: 0.3552 - val_accuracy: 0.9124 - val_loss: 0.3213
# Epoch 28/30
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 38s 261ms/step - accuracy: 0.8674 - loss: 0.3193 - val_accuracy: 0.9074 - val_loss: 0.3064
# Epoch 29/30
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 39s 261ms/step - accuracy: 0.8625 - loss: 0.3251 - val_accuracy: 0.9134 - val_loss: 0.3100
# Epoch 30/30
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 39s 261ms/step - accuracy: 0.8470 - loss: 0.3851 - val_accuracy: 0.9144 - val_loss: 0.3036
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 401ms/step - accuracy: 0.8786 - loss: 0.4436
#
# Test Accuracy: 0.9141
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 8s 223ms/step
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_31/88460795.py in <cell line: 0>()
#      88 y_true = test_generator.classes
#      89 y_pred_probs = model.predict(test_generator)
# ---> 90 y_pred = np.argmax(y_pred_probs, axis=1)
#      91
#      92 # Classification report
#
# NameError: name 'np' is not defined

# %%
test_loss, test_acc = model.evaluate(test_generator)
print(f"Test accuracy: {test_acc:.4f}")

# %% [markdown]
# With Augmentation
