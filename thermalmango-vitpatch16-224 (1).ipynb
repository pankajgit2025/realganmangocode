# %%
import tensorflow as tf
from transformers import ViTFeatureExtractor, TFAutoModel
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Dense, Dropout, Input
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report
import os

# Load ViT feature extractor and model
feature_extractor = ViTFeatureExtractor.from_pretrained('google/vit-base-patch16-224')
vit_model = TFAutoModel.from_pretrained('google/vit-base-patch16-224')
vit_model.trainable = False  # Freeze ViT

# Paths
train_dir = '/kaggle/input/thermalmango224x224/THERMALGANDataset224X224/train'
val_dir = '/kaggle/input/thermalmango224x224/THERMALGANDataset224X224/val'
test_dir = '/kaggle/input/thermalmango224x224/THERMALGANDataset224X224/test'

img_size = (224, 224)
batch_size = 32
num_classes = 6

# Load datasets
train_ds = tf.keras.utils.image_dataset_from_directory(train_dir, image_size=img_size, batch_size=batch_size)
val_ds = tf.keras.utils.image_dataset_from_directory(val_dir, image_size=img_size, batch_size=batch_size)
test_ds = tf.keras.utils.image_dataset_from_directory(test_dir, image_size=img_size, batch_size=batch_size, shuffle=False)

class_names = train_ds.class_names

# Convert images to features
def extract_features(dataset):
    all_features, all_labels = [], []
    for batch_images, batch_labels in tqdm(dataset, desc="Extracting ViT features"):
        images_uint8 = tf.image.convert_image_dtype(batch_images, dtype=tf.uint8)
        images_np = images_uint8.numpy()
        pixel_values = feature_extractor(images_np, return_tensors='tf')['pixel_values']
        outputs = vit_model(pixel_values, training=False)
        cls_embeddings = outputs.last_hidden_state[:, 0, :]  # CLS token
        all_features.append(cls_embeddings.numpy())
        all_labels.append(batch_labels.numpy())
    features = np.vstack(all_features)
    labels = tf.keras.utils.to_categorical(np.concatenate(all_labels), num_classes)
    return features, labels

# Extract ViT features
X_train, y_train = extract_features(train_ds)
X_val, y_val = extract_features(val_ds)
X_test, y_test = extract_features(test_ds)

# Classifier head
classifier = Sequential([
    Dense(256, activation='relu', input_shape=(X_train.shape[1],)),
    Dropout(0.5),
    Dense(num_classes, activation='softmax')
])

classifier.compile(
    optimizer='adam',
    loss=tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.1),
    metrics=['accuracy']
)

# Callbacks
callbacks = [
    EarlyStopping(monitor='val_accuracy', patience=5, restore_best_weights=True),
    ModelCheckpoint('best_vit_head.keras', monitor='val_accuracy', save_best_only=True),
    ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=3, verbose=1)
]

# Train
history = classifier.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=30, callbacks=callbacks)

# Save models
classifier.save('final_vit_head_model.keras')
classifier.save('final_vit_head_model.h5')

# Plot accuracy
plt.figure(figsize=(12, 6))
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Val Accuracy')
plt.legend(), plt.grid(True), plt.title('Train vs Val Accuracy'), plt.xlabel('Epoch'), plt.ylabel('Accuracy')
plt.show()

# Test results
test_loss, test_acc = classifier.evaluate(X_test, y_test)
print(f"Test Loss: {test_loss:.4f}, Test Accuracy: {test_acc:.4f}")

# Confusion matrix
y_pred_probs = classifier.predict(X_test)
y_pred = np.argmax(y_pred_probs, axis=1)
y_true = np.argmax(y_test, axis=1)

cm = confusion_matrix(y_true, y_pred)
disp = ConfusionMatrixDisplay(cm, display_labels=class_names)
disp.plot(cmap='Blues', xticks_rotation=45)
plt.title("Confusion Matrix")
plt.show()

# Classification report
report = classification_report(y_true, y_pred, target_names=class_names, digits=4)
print("Classification Report:\n", report)
with open("classification_report_vit.txt", "w") as f:
    f.write(report)

# ---------------------------------------------------------
# ✅ Grad-CAM Visualization
# ---------------------------------------------------------

# Re-load a few original test images for Grad-CAM
raw_test_images, raw_labels = [], []
for batch_images, batch_labels in test_ds.take(1):
    raw_test_images.append(batch_images)
    raw_labels.append(batch_labels)

raw_test_images = tf.concat(raw_test_images, axis=0)
raw_labels = tf.concat(raw_labels, axis=0)

def preprocess_for_vit(img_batch):
    img_batch_uint8 = tf.image.convert_image_dtype(img_batch, dtype=tf.uint8)
    return feature_extractor(img_batch_uint8.numpy(), return_tensors='tf')['pixel_values']

def get_grad_cam_heatmap(image, classifier_model, last_conv_layer=None):
    with tf.GradientTape() as tape:
        pixel_values = preprocess_for_vit(image[None])[0]
        vit_out = vit_model(pixel_values[None], training=False).last_hidden_state  # shape: (1, 197, 768)
        cls_token = vit_out[:, 0, :]  # (1, 768)

        tape.watch(cls_token)
        preds = classifier_model(cls_token)
        top_class = tf.argmax(preds[0])
        top_output = preds[:, top_class]

    grads = tape.gradient(top_output, cls_token)  # gradient w.r.t. CLS token
    pooled_grads = tf.reduce_mean(grads, axis=1)

    heatmap = tf.reduce_sum(tf.multiply(pooled_grads, cls_token), axis=1)
    heatmap = tf.maximum(heatmap, 0) / tf.math.reduce_max(heatmap)
    return heatmap.numpy()[0], int(top_class)

def display_gradcam(image, heatmap, label, pred_label, class_names):
    plt.figure(figsize=(6, 3))
    plt.subplot(1, 2, 1)
    plt.imshow(tf.cast(image, tf.uint8))
    plt.title(f"True: {class_names[label]}\nPred: {class_names[pred_label]}")
    plt.axis("off")

    plt.subplot(1, 2, 2)
    plt.imshow(tf.cast(image, tf.uint8))
    plt.imshow(heatmap.reshape((1, 1)), cmap='jet', alpha=0.5, extent=(0, 224, 224, 0))
    plt.title("Grad-CAM Heatmap (CLS)")
    plt.axis("off")
    plt.show()

# Run Grad-CAM on first 5 test images
for i in range(5):
    image = raw_test_images[i]
    true_label = int(raw_labels[i])
    heatmap, pred_label = get_grad_cam_heatmap(image, classifier)
    display_gradcam(image, heatmap, true_label, pred_label, class_names)
# Out:
# 2025-06-10 21:33:24.889629: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1749591205.352015      35 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1749591205.462693      35 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# preprocessor_config.json:   0%|          | 0.00/160 [00:00<?, ?B/s]
# /usr/local/lib/python3.11/dist-packages/transformers/models/vit/feature_extraction_vit.py:28: FutureWarning: The class ViTFeatureExtractor is deprecated and will be removed in version 5 of Transformers. Please use ViTImageProcessor instead.
#   warnings.warn(
# config.json:   0%|          | 0.00/69.7k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/346M [00:00<?, ?B/s]
# I0000 00:00:1749591247.955095      35 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13942 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1749591247.955838      35 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13942 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFViTModel: ['classifier.weight', 'classifier.bias']
# - This IS expected if you are initializing TFViTModel from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFViTModel from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights or buffers of the TF 2.0 model TFViTModel were not initialized from the PyTorch model and are newly initialized: ['vit.pooler.dense.weight', 'vit.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Found 42000 files belonging to 6 classes.
# Found 9000 files belonging to 6 classes.
# Found 9000 files belonging to 6 classes.
# Extracting ViT features:   0%|          | 0/1313 [00:00<?, ?it/s]I0000 00:00:1749591324.809858      35 cuda_dnn.cc:529] Loaded cuDNN version 90300
# Extracting ViT features: 100%|██████████| 1313/1313 [21:50<00:00,  1.00it/s]
# Extracting ViT features: 100%|██████████| 282/282 [04:41<00:00,  1.00it/s]
# Extracting ViT features: 100%|██████████| 282/282 [04:41<00:00,  1.00it/s]
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/30
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1749593199.491534     110 service.cc:148] XLA service 0x7c4788016750 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1749593199.493310     110 service.cc:156]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1749593199.493338     110 service.cc:156]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
#   74/1313 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.4587 - loss: 1.6483
# I0000 00:00:1749593201.223075     110 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.7528 - loss: 0.9863 - val_accuracy: 0.8976 - val_loss: 0.6844 - learning_rate: 0.0010
# Epoch 2/30
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8935 - loss: 0.7106 - val_accuracy: 0.9320 - val_loss: 0.6145 - learning_rate: 0.0010
# Epoch 3/30
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9139 - loss: 0.6734 - val_accuracy: 0.9394 - val_loss: 0.5981 - learning_rate: 0.0010
# Epoch 4/30
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9232 - loss: 0.6567 - val_accuracy: 0.9420 - val_loss: 0.5921 - learning_rate: 0.0010
# Epoch 5/30
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9338 - loss: 0.6388 - val_accuracy: 0.9492 - val_loss: 0.5764 - learning_rate: 0.0010
# Epoch 6/30
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9362 - loss: 0.6315 - val_accuracy: 0.9527 - val_loss: 0.5703 - learning_rate: 0.0010
# Epoch 7/30
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9457 - loss: 0.6181 - val_accuracy: 0.9556 - val_loss: 0.5701 - learning_rate: 0.0010
# Epoch 8/30
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9467 - loss: 0.6134 - val_accuracy: 0.9568 - val_loss: 0.5650 - learning_rate: 0.0010
# Epoch 9/30
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9484 - loss: 0.6080 - val_accuracy: 0.9541 - val_loss: 0.5691 - learning_rate: 0.0010
# Epoch 10/30
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9519 - loss: 0.6038 - val_accuracy: 0.9564 - val_loss: 0.5640 - learning_rate: 0.0010
# Epoch 11/30
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9521 - loss: 0.6018 - val_accuracy: 0.9584 - val_loss: 0.5643 - learning_rate: 0.0010
# Epoch 12/30
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9567 - loss: 0.5942 - val_accuracy: 0.9586 - val_loss: 0.5570 - learning_rate: 0.0010
# Epoch 13/30
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9589 - loss: 0.5890 - val_accuracy: 0.9611 - val_loss: 0.5558 - learning_rate: 0.0010
# Epoch 14/30
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9573 - loss: 0.5945 - val_accuracy: 0.9576 - val_loss: 0.5574 - learning_rate: 0.0010
# Epoch 15/30
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9612 - loss: 0.5862 - val_accuracy: 0.9631 - val_loss: 0.5512 - learning_rate: 0.0010
# Epoch 16/30
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9609 - loss: 0.5860 - val_accuracy: 0.9633 - val_loss: 0.5492 - learning_rate: 0.0010
# Epoch 17/30
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9624 - loss: 0.5843 - val_accuracy: 0.9612 - val_loss: 0.5497 - learning_rate: 0.0010
# Epoch 18/30
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9640 - loss: 0.5809 - val_accuracy: 0.9602 - val_loss: 0.5510 - learning_rate: 0.0010
# Epoch 19/30
# 1305/1313 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9659 - loss: 0.5767
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9659 - loss: 0.5767 - val_accuracy: 0.9626 - val_loss: 0.5540 - learning_rate: 0.0010
# Epoch 20/30
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9740 - loss: 0.5610 - val_accuracy: 0.9664 - val_loss: 0.5352 - learning_rate: 2.0000e-04
# Epoch 21/30
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9764 - loss: 0.5520 - val_accuracy: 0.9664 - val_loss: 0.5351 - learning_rate: 2.0000e-04
# Epoch 22/30
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9768 - loss: 0.5512 - val_accuracy: 0.9677 - val_loss: 0.5329 - learning_rate: 2.0000e-04
# Epoch 23/30
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9794 - loss: 0.5491 - val_accuracy: 0.9680 - val_loss: 0.5337 - learning_rate: 2.0000e-04
# Epoch 24/30
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9806 - loss: 0.5479 - val_accuracy: 0.9684 - val_loss: 0.5327 - learning_rate: 2.0000e-04
# Epoch 25/30
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9801 - loss: 0.5470 - val_accuracy: 0.9691 - val_loss: 0.5324 - learning_rate: 2.0000e-04
# Epoch 26/30
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9808 - loss: 0.5466 - val_accuracy: 0.9679 - val_loss: 0.5325 - learning_rate: 2.0000e-04
# Epoch 27/30
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9795 - loss: 0.5458 - val_accuracy: 0.9672 - val_loss: 0.5324 - learning_rate: 2.0000e-04
# Epoch 28/30
# 1303/1313 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9794 - loss: 0.5465
# Epoch 28: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9794 - loss: 0.5465 - val_accuracy: 0.9666 - val_loss: 0.5337 - learning_rate: 2.0000e-04
# Epoch 29/30
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9822 - loss: 0.5438 - val_accuracy: 0.9683 - val_loss: 0.5297 - learning_rate: 4.0000e-05
# Epoch 30/30
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9829 - loss: 0.5400 - val_accuracy: 0.9680 - val_loss: 0.5300 - learning_rate: 4.0000e-05
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9783 - loss: 0.5125
# Test Loss: 0.5363, Test Accuracy: 0.9670
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Classification Report:
#                      precision    recall  f1-score   support
#
#        ANTHRECNOSE     0.9728    0.9767    0.9747      1500
#            DIEBACK     0.9803    0.9933    0.9868      1500
#   GALLMILDGEDAMAGE     0.9799    0.9733    0.9766      1500
#            HEALTHY     0.9646    0.9813    0.9729      1500
# INSECTDAMAGEWEBBER     0.9453    0.9440    0.9446      1500
#         LEAFBLIGHT     0.9589    0.9333    0.9459      1500
#
#           accuracy                         0.9670      9000
#          macro avg     0.9669    0.9670    0.9669      9000
#       weighted avg     0.9669    0.9670    0.9669      9000

# %%
# Print all accuracies
print(f"Final Training Accuracy:   {final_train_acc:.4f}")
print(f"Final Validation Accuracy: {final_val_acc:.4f}")
print(f"Test Accuracy:             {test_acc:.4f}")
